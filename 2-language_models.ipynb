# %% [markdown]
# # Assignment #2: Language models
# Author: Pierre Nugues
#
# Student: Van Duy Dang

# %% [markdown]
# ## Objectives

# %% [markdown]
# The objectives of this assignment are to:
# * Write a program to find n-gram statistics
# * Compute the probability of a sentence
# * Know what a language model is
# * Write a short report of 1 to 2 pages on the assignment

# %% [markdown]
# ## Submission

# %% [markdown]
# Once you have written all the missing code and run all the cells, you will show it to an instructor that will pass you.

# %% [markdown]
# ## Organization

# %% [markdown]
# * Each group will have to write Python programs to count unigrams, bigrams, and trigrams in a corpus of approximately one million words and to determine the probability of a sentence.
# * You can test you regular expression using the regex101.com site
# * Each student will have to write a short report of one to two pages and comment briefly the results. In your report, you must produce the tabulated results of your analysis as described below.

# %% [markdown]
# ## Programming

# %% [markdown]
# ### Imports

# %% [markdown]
# Some imports you may need. Add others as needed.

# %%
import bz2
import math
import os
import regex as re
import requests
import sys
from zipfile import ZipFile

# %% [markdown]
# ### Collecting and analyzing a corpus

# %% [markdown]
# Retrieve a corpus of novels by Selma Lagerl&ouml;f from this URL:
# <a href="https://github.com/pnugues/ilppp/blob/master/programs/corpus/Selma.txt">
#     <tt>https://github.com/pnugues/ilppp/blob/master/programs/corpus/Selma.txt</tt>
# </a>. The text of these novels was extracted
# from <a href="https://litteraturbanken.se/forfattare/LagerlofS/titlar">Lagerlöf arkivet</a> at
# <a href="https://litteraturbanken.se/">Litteraturbanken</a>.

# %%
# You may have to adjust the path
corpus = open('Selma.txt', encoding='utf8').read()

# %% [markdown]
# Run the <a href="https://github.com/pnugues/ilppp/tree/master/programs/ch02/python">concordance
# program </a> to print the lines containing a specific word, for instance <i>Nils</i>.

# %%
pattern = 'Nils Holgersson'
width = 25

# %%
# spaces match tabs and newlines
pattern = re.sub(' ', r'\\s+', pattern)
# Replaces newlines with spaces in the text
clean_corpus = re.sub(r'\s+', ' ', corpus)
concordance = ('(.{{0,{width}}}{pattern}.{{0,{width}}})'
               .format(pattern=pattern, width=width))
for match in re.finditer(concordance, clean_corpus):
    print(match.group(1))
# print the string with 0..width characters on either side
# Out:
# Selma Lagerlöf Nils Holgerssons underbara resa genom Sv
# ! Se på Tummetott! Se på Nils Holgersson Tummetott!» Genast vände
# r,» sade han. »Jag heter Nils Holgersson och är son till en husma
# lden. »Inte är det värt, Nils Holgersson, att du är ängslig eller
#  i dem. På den tiden, då Nils Holgersson drog omkring med vildgäs
# ulle allt visa honom vad Nils Holgersson från Västra Vemmenhög va
# om ägde rum det året, då Nils Holgersson for omkring med vildgäss
# m vad det kan kosta dem. Nils Holgersson hade inte haft förstånd
# de det inte mer sägas om Nils Holgersson, att han inte tyckte om
#  Rosenbom?» För där stod Nils Holgersson mitt uppe på Rosenboms n
#  Med ens fingo de syn på Nils Holgersson, och då sköt den store v
# vila. När vildgässen och Nils Holgersson äntligen hade letat sig
#  slags arbetare. Men vad Nils Holgersson inte såg, det var, att s
# nde han fråga, och om då Nils Holgersson sade nej, började han ge
# de lille Mats, och om nu Nils Holgersson också hade tegat, så had
# åg så försmädlig ut, att Nils Holgersson kastade sig över honom f
#  brodern. Och inte ville Nils Holgersson slåss med en tös, utan h
# örkar. På den tiden, när Nils Holgersson for omkring med vildgäss
#  ryckte omkull honom. Om Nils Holgersson genast hade ropat på hjä
# u reda dig på egen hand, Nils Holgersson,» sade han då till sig s
# r satte Fumle-Drumle ner Nils Holgersson på bottnen av en sandgro
# mlingarna. – »Jo, jag är Nils Holgersson från Västra Vemmenhög, s
# rakten. På den tiden, då Nils Holgersson for omkring med vildgäss
# Jo, det står – Det står: Nils Holgersson fr. V. Vemmenhög.» »Det
# visan 1 Sveriges karta 2 Nils Holgerssons underbara resa genom Sv
# admalsvåden 233 ________ Nils Holgerssons underbara resa genom Sv
# R. Tolv år ungefär innan Nils Holgersson hade börjat resa omkring
# och leta efter föda, men Nils Holgersson hade på morgonen tappat
# ill i Närke det året, då Nils Holgersson for fram över landskapet
# hade flyttat tassen över Nils Holgerssons ansikte, så att den sta
# 29 april. Denna dag fick Nils Holgersson se södra Dalarna. Vildgä
# rliga sjön. Det året, då Nils Holgersson for med vildgässen genom
# t skänka upptäckten till Nils Holgersson. Det var ju både det tro
#  som sången varade, stod Nils Holgersson och lyssnade till den, m
# ova på en vassrugge. Vad Nils Holgersson angår, så var han för hu
# e svårt för en sådan som Nils Holgersson att finna en farkost. Ha
# r de hade kommit mittför Nils Holgersson, slogo de sig ner på ett
#  5 maj. På den tiden, då Nils Holgersson drog genom landet med vi
# an vara bra lycklig. Att Nils Holgersson, som för ett par timmar
#  afton. Och således hade Nils Holgersson fått se studenterna, när
# nger under marschen. Men Nils Holgersson hade tyckt, att det inte
# och glädja så som dessa. Nils Holgersson hade mest sett på studen
# m, stannade han. »Jag är Nils Holgersson från Västra Vemmenhög,»
#  Ett par år före det, då Nils Holgersson drog omkring med vildgäs
#  detsamma fattade han om Nils Holgersson med sin stora fot, höjde
# t ingen mer än den lilla Nils Holgersson, som följde henne. Solen
#  voro klädda med is, och Nils Holgersson ville följa henne dit in
# t Lappland är mitt!» Men Nils Holgersson hade blivit så ängslig,
#  över klippväggarna, och Nils Holgersson kunde förstå, att det va
#  SJUKDOMEN. Det året, då Nils Holgersson for omkring med vildgäss
# jligt att undgå den. Vad Nils Holgersson beträffar, så hade han h
# hade hon slagit klorna i Nils Holgerssons skuldra och hackade eft
# g, att just det året, då Nils Holgersson for omkring med vildgäss
#  lönt att vara bedrövad, Nils Holgersson,» sade solen. »Världen ä
# åga om han inte kunde ge Nils Holgersson bättre villkor. ’Det öns
# du vill,’ sade han. ’Med Nils Holgersson blir det ändå så, som ja
# a haft av honom. Ja, säg Nils Holgersson, att föräldrarna redan h
# Västergötland. Den lille Nils Holgersson hade krupit upp på en la
#  honom sämre.» Den lille Nils Holgersson hade följt med barnen he
# e bara störa.» Då tyckte Nils Holgersson, att när ingen annan gjo
# n färdig att följa det.» Nils Holgersson sprang raskt neråt vägen
# rott mellan de unga. Vad Nils Holgersson beträffar, så hade han i
# on gav sig tid att se på Nils Holgersson, innan hon stötte till.
#  ändå alldeles olik. Den Nils Holgersson, som hade farit bort i v
#  tro det. Välkommen hem, Nils Holgersson, välkommen hem! Det här
# mig här på gården,» sade Nils Holgersson. »Min egen mor tror, att
# on riktig sjukdom,» sade Nils Holgersson. »Jag får försöka ställa
# in kniv här på din hov?» Nils Holgersson var nätt och jämnt färdi
# sslingen, som var så lik Nils Holgersson, att om det inte var han
# pojken fanns i närheten. Nils Holgersson hörde honom nog, men han
# ottrar ihop ett tack för Nils Holgersson? Vad skulle det ha blivi

# %% [markdown]
# Run a simple <a href="https://github.com/pnugues/ilppp/tree/master/programs/ch05/python">tokenization
# program</a> on your corpus.

# %%
def tokenize(text):
    words = re.findall('\p{L}+', text)
    return words

# %%
words = tokenize(corpus)
words[:10]
# Out:
# ['Selma',
#  'Lagerlöf',
#  'Nils',
#  'Holgerssons',
#  'underbara',
#  'resa',
#  'genom',
#  'Sverige',
#  'Första',
#  'bandet']

# %% [markdown]
# Count the number of unique words in the original corpus and when setting all the words in lowercase

# %% [markdown]
# Original text

# %%
lowercase_words = [word.lower() for word in words]
len(set(lowercase_words))
# Out:
# 41032

# %%
# Write your code here
len(set(words))
# Out:
# 44256

# %% [markdown]
# Lowercased text

# %%
# Write your code here
lowercase_words = [word.lower() for word in words]
len(set(lowercase_words))
# Out:
# 41032

# %% [markdown]
# ### Segmenting a corpus

# %% [markdown]
# You will write a program to tokenize your text, insert `<s>` and `</s>` tags to delimit sentences, and set all the words in lowercase letters. In the end, you will only keep the words.

# %% [markdown]
# #### Normalizing

# %% [markdown]
# Write a regular expression that matches all the characters that are neither a letter nor a punctuation sign. The punctuations signs will be the followings: `.;:?!`. In your regex, use the same order. For the definition of a letter, use a Unicode regex. You will call the regex string `nonletter`

# %%
# Write your code
nonletter = '[^.;:?!\p{L}]+'

# %% [markdown]
# Write a `clean()` function that replaces all the characters that are neither a letter nor a punctuation sign with a space. The punctuations signs will be the followings: `.;:?!`.   For the sentence:
#
# _En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa._
#
# the result will be:
#
# `En gång hade de på Mårbacka en barnpiga som hette Back Kajsa.`

# %%
# Write your code here
def clean(text):
    cleantext = re.sub(nonletter, " ", text)
    cleantext = cleantext.replace("  ", " ")
    return cleantext

# %%
test_para = 'En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa. \
Hon var nog sina tre alnar lång, hon hade ett stort, grovt ansikte med stränga, mörka drag, \
hennes händer voro hårda och fulla av sprickor, som barnens hår fastnade i, \
när hon kammade dem, och till humöret var hon dyster och sorgbunden.'

# %%
test_para = clean(test_para)
test_para
# Out:
# 'En gång hade de på Mårbacka en barnpiga som hette Back Kajsa. Hon var nog sina tre alnar lång hon hade ett stort grovt ansikte med stränga mörka drag hennes händer voro hårda och fulla av sprickor som barnens hår fastnade i när hon kammade dem och till humöret var hon dyster och sorgbunden.'

# %%
print(corpus[:200])
# Out:
# Selma Lagerlöf
#
#
# Nils Holgerssons underbara resa genom Sverige. Första bandet
#
#
#
#
#
# Bokutgåva
#
#
# Albert Bonniers förlag, Stockholm 1907.
#
#
#
#
# DEN KRISTLIGA DAGVISAN.
#
#
#
#
#
# Den signade dag, som vi nu här s

# %%
print(clean(corpus[:200]))
# Out:
# Selma Lagerlöf Nils Holgerssons underbara resa genom Sverige. Första bandet Bokutgåva Albert Bonniers förlag Stockholm . DEN KRISTLIGA DAGVISAN. Den signade dag som vi nu här s

# %% [markdown]
# #### Segmenter

# %% [markdown]
# In this section, you will write a sentence segmenter that will delimit each sentence with `</s>` and `<s>` symbols. For example the sentence:
#
# _En gång hade de på Mårbacka en barnpiga, som hette Back-Kajsa._
#
# will be bracketed as:
#
# `<s> En gång hade de på Mårbacka en barnpiga som hette Back-Kajsa </s>`
#
# As algorithm, you will use a simple heuristics to detect the sentence boundaries: A sentence starts with a capital letter and ends with a period-equivalent punctuation sign. You will write a regex to match these boundaries with a regular expression and you will insert `</s>\n<s>` symbols with a substitution function.

# %% [markdown]
# ##### Detecting sentence boundaries

# %% [markdown]
# Write a regular expression that matches a punctuation, a sequence of spaces, and an uppercase letter. Call this regex string `sentence_boundaries`. In the regex, you will remember the value of the uppercase letter using a backreference. Use the Unicode regexes for the letters and the spaces. Do not use `\s`.

# %%
# Write your code here
#(\p{Lu}) captures an uppercase letter using a capturing group and remembers its value.
sentence_boundaries = r'[.;:?!]+\p{Z}+(\p{Lu})'

# %% [markdown]
# ##### Replacement markup

# %% [markdown]
# Write a string to replace the matched boundaries with the sentence boundary markup. Remember that a sentence ends with `</s>` and starts with `<s>` and that there is one sentence per line. Hint: The markup is `</s>\n<s>`. Remember also that the first letter of your sentence is in a regex backreference. Call the regex string `sentence_markup`.

# %%
# Write your code here
#\1 is a backreference to match the text matched by the first capturing group.
sentence_markup = r' </s>\n<s> \1'

# %% [markdown]
# ##### Applying the substitution

# %% [markdown]
# Use your regexes to segment your text. Use the string `sentence_boundaries`, `sentence_markup`, and `test_para` as input and `text` as output.

# %%
# Write your code here
text = re.sub(sentence_boundaries, sentence_markup, test_para)

# %%
print(text)
# Out:
# En gång hade de på Mårbacka en barnpiga som hette Back Kajsa </s>
# <s> Hon var nog sina tre alnar lång hon hade ett stort grovt ansikte med stränga mörka drag hennes händer voro hårda och fulla av sprickor som barnens hår fastnade i när hon kammade dem och till humöret var hon dyster och sorgbunden.

# %% [markdown]
# Insert markup codes in the beginning and end of the text

# %%
# Write your code here
text = '<s> ' + text + ' </s>'

# %%
print(text)
# Out:
# <s> En gång hade de på Mårbacka en barnpiga som hette Back Kajsa </s>
# <s> Hon var nog sina tre alnar lång hon hade ett stort grovt ansikte med stränga mörka drag hennes händer voro hårda och fulla av sprickor som barnens hår fastnade i när hon kammade dem och till humöret var hon dyster och sorgbunden. </s>

# %% [markdown]
# Replace the space duplicates with one space and remove the punctuation signs. For the spaces, use the Unicode regex. Do not use `\s`.

# %%
# Write your code here
# Replace the space duplicates with one space
text = re.sub(r'\p{Z}+', ' ', text)
# Remove the punctuation signs
text = re.sub(r'[.;:?!]', '', text)

# %%
print(text)
# Out:
# <s> En gång hade de på Mårbacka en barnpiga som hette Back Kajsa </s>
# <s> Hon var nog sina tre alnar lång hon hade ett stort grovt ansikte med stränga mörka drag hennes händer voro hårda och fulla av sprickor som barnens hår fastnade i när hon kammade dem och till humöret var hon dyster och sorgbunden </s>

# %% [markdown]
# Write a `segment_sentences(text)` function to gather the code in the Segmenter section and set the text in lowercase

# %%
# Write your code here
def segment_sentences(text):
    #\p{Z}* matches zero or more Unicode spaces
    #(\p{Lu}) captures an uppercase letter using a capturing group and remembers its value.
    #sentence_boundaries = r'[.;:?!]\p{Z}*(\p{Lu})'
    sentence_boundaries = r'[.;:?!]+\p{Z}+(\p{Lu})'
    #\1 is a backreference to match the text matched by the first capturing group.
    sentence_markup = r' </s>\n<s> \1'
    text = re.sub(sentence_boundaries, sentence_markup, text)
    text = '<s> ' + text + ' </s>'
    # Replace the space duplicates with one space
    text = re.sub(r'\p{Z}+', ' ', text)
    # Remove the punctuation signs
    text = re.sub(r'[.;:?!]', '', text)

    return text.lower()

# %%
print(segment_sentences(test_para))
# Out:
# <s> en gång hade de på mårbacka en barnpiga som hette back kajsa </s>
# <s> hon var nog sina tre alnar lång hon hade ett stort grovt ansikte med stränga mörka drag hennes händer voro hårda och fulla av sprickor som barnens hår fastnade i när hon kammade dem och till humöret var hon dyster och sorgbunden </s>

# %% [markdown]
# Estimate qualitatively the accuracy of your program.

# %% [markdown]
# #### Tokenizing the corpus

# %% [markdown]
# Clean and segment the corpus using the functions you have written

# %%
# Write your code here
corpus = clean(corpus)
corpus = segment_sentences(corpus)

# %% [markdown]
# The result should be a normalized text without punctuation signs where all the sentences are delimited with `<s>` and `</s>` tags. The five last lines of the text should look like this. You may have some small differences.

# %%
print(corpus[-557:])
# Out:
# <s> hon hade fått större kärlek av sina föräldrar än någon annan han visste och sådan kärlek måste vändas i välsignelse </s>
# <s> då prästen sade detta kom alla människor att se bort mot klara gulla och de förundrade sig över vad de såg </s>
# <s> prästens ord tycktes redan ha gått i uppfyllelse </s>
# <s> där stod klara fina gulleborg ifrån skrolycka hon som var uppkallad efter själva solen vid sina föräldrars grav och lyste som en förklarad </s>
# <s> hon var likaså vacker som den söndagen då hon gick till kyrkan i den röda klänningen om inte vackrare </s>

# %% [markdown]
# You will now create a list of words from your string. You will consider that a space or a carriage return is an item separator

# %%
# Write your code here
words = re.split(r'[ \n]', corpus)

# %% [markdown]
# The five last lines of the corpus should like this:

# %%
print(words[-101:])
# Out:
# ['<s>', 'hon', 'hade', 'fått', 'större', 'kärlek', 'av', 'sina', 'föräldrar', 'än', 'någon', 'annan', 'han', 'visste', 'och', 'sådan', 'kärlek', 'måste', 'vändas', 'i', 'välsignelse', '</s>', '<s>', 'då', 'prästen', 'sade', 'detta', 'kom', 'alla', 'människor', 'att', 'se', 'bort', 'mot', 'klara', 'gulla', 'och', 'de', 'förundrade', 'sig', 'över', 'vad', 'de', 'såg', '</s>', '<s>', 'prästens', 'ord', 'tycktes', 'redan', 'ha', 'gått', 'i', 'uppfyllelse', '</s>', '<s>', 'där', 'stod', 'klara', 'fina', 'gulleborg', 'ifrån', 'skrolycka', 'hon', 'som', 'var', 'uppkallad', 'efter', 'själva', 'solen', 'vid', 'sina', 'föräldrars', 'grav', 'och', 'lyste', 'som', 'en', 'förklarad', '</s>', '<s>', 'hon', 'var', 'likaså', 'vacker', 'som', 'den', 'söndagen', 'då', 'hon', 'gick', 'till', 'kyrkan', 'i', 'den', 'röda', 'klänningen', 'om', 'inte', 'vackrare', '</s>']

# %%
len(words)
# Out:
# 1041575

# %% [markdown]
# ### Counting unigrams and bigrams

# %% [markdown]
# Read and try programs to compute the frequency of unigrams and bigrams of the training set: [<a
#             href="https://github.com/pnugues/ilppp/tree/master/programs/ch05/python">Program folder</a>].

# %% [markdown]
# #### Unigrams

# %%
def unigrams(words):
    frequency = {}
    for i in range(len(words)):
        if words[i] in frequency:
            frequency[words[i]] += 1
        else:
            frequency[words[i]] = 1
    return frequency

# %% [markdown]
# We compute the frequencies.

# %%
frequency = unigrams(words)
list(frequency.items())[:20]
# Out:
# [('<s>', 59047),
#  ('selma', 52),
#  ('lagerlöf', 270),
#  ('nils', 87),
#  ('holgerssons', 6),
#  ('underbara', 23),
#  ('resa', 317),
#  ('genom', 688),
#  ('sverige', 56),
#  ('</s>', 59047),
#  ('första', 525),
#  ('bandet', 6),
#  ('bokutgåva', 11),
#  ('albert', 15),
#  ('bonniers', 11),
#  ('förlag', 11),
#  ('stockholm', 77),
#  ('den', 11624),
#  ('kristliga', 2),
#  ('dagvisan', 2)]

# %%
for word in sorted(frequency.keys(), key=frequency.get, reverse=True):
        print(word, '\t', frequency[word])
# Out:
# <s> 	 59047
# </s> 	 59047
# och 	 36356
# att 	 28020
# han 	 21589
# det 	 21108
# i 	 16508
# som 	 16288
# på 	 14250
# en 	 13514
# hon 	 13313
# hade 	 13198
# var 	 12090
# de 	 11942
# den 	 11624
# inte 	 11355
# jag 	 9511
# för 	 9443
# sig 	 9250
# så 	 9149
# med 	 9140
# till 	 9139
# men 	 8144
# om 	 8075
# är 	 6290
# honom 	 5809
# av 	 5435
# skulle 	 5433
# ett 	 5060
# då 	 4919
# har 	 4666
# du 	 4359
# där 	 4238
# sade 	 4138
# nu 	 4084
# henne 	 4031
# kunde 	 3251
# dem 	 3196
# ut 	 2835
# när 	 2772
# mig 	 2689
# kom 	 2639
# än 	 2558
# sin 	 2513
# detta 	 2482
# över 	 2454
# upp 	 2450
# alla 	 2355
# från 	 2347
# man 	 2322
# såg 	 2284
# hans 	 2219
# ha 	 2131
# här 	 2107
# vi 	 2105
# kan 	 2078
# allt 	 2036
# fram 	 2019
# in 	 2009
# hur 	 1996
# något 	 1996
# se 	 1989
# vad 	 1961
# vid 	 1952
# utan 	 1921
# ska 	 1886
# efter 	 1831
# få 	 1830
# ej 	 1806
# vara 	 1803
# väl 	 1800
# gick 	 1797
# varit 	 1721
# bara 	 1709
# hennes 	 1629
# ingen 	 1593
# gå 	 1590
# ville 	 1571
# mot 	 1526
# dig 	 1519
# ni 	 1513
# blev 	 1488
# under 	 1479
# nog 	 1468
# hela 	 1463
# ner 	 1420
# aldrig 	 1420
# åt 	 1413
# bli 	 1407
# någon 	 1379
# voro 	 1362
# komma 	 1343
# mycket 	 1340
# gång 	 1332
# eller 	 1332
# stora 	 1324
# gamla 	 1298
# af 	 1290
# sina 	 1278
# andra 	 1270
# också 	 1265
# ju 	 1250
# tänkte 	 1224
# mer 	 1217
# stod 	 1192
# göra 	 1158
# ingmar 	 1137
# vill 	 1127
# satt 	 1126
# ur 	 1125
# fick 	 1112
# måste 	 1094
# sedan 	 1092
# sitt 	 1070
# bort 	 1058
# pojken 	 1028
# låg 	 1017
# började 	 1006
# å 	 982
# oss 	 974
# annat 	 968
# säga 	 952
# stor 	 951
# dag 	 942
# ja 	 938
# min 	 920
# får 	 906
# denna 	 886
# kommit 	 879
# visste 	 874
# tyckte 	 865
# därför 	 864
# tala 	 845
# själv 	 834
# er 	 833
# kommer 	 824
# alldeles 	 821
# fått 	 818
# vet 	 816
# hem 	 814
# gjorde 	 796
# par 	 794
# sa 	 778
# mor 	 775
# just 	 758
# kände 	 753
# snart 	 752
# blivit 	 747
# skall 	 729
# tillbaka 	 726
# far 	 723
# ingenting 	 720
# deras 	 716
# rätt 	 716
# många 	 715
# år 	 706
# fanns 	 702
# sådan 	 702
# hörde 	 699
# samma 	 693
# genom 	 688
# omkring 	 684
# igen 	 671
# öfver 	 663
# ännu 	 662
# sett 	 657
# ord 	 656
# små 	 648
# gått 	 647
# ta 	 644
# ser 	 638
# tog 	 638
# dessa 	 637
# går 	 633
# kunna 	 632
# barn 	 619
# några 	 612
# säger 	 599
# människor 	 594
# liten 	 592
# stund 	 585
# annan 	 582
# tid 	 577
# jan 	 577
# blir 	 576
# medan 	 568
# långt 	 567
# kanske 	 556
# länge 	 555
# höll 	 554
# helt 	 551
# höra 	 551
# gertrud 	 551
# gjort 	 548
# hos 	 546
# kvar 	 545
# lilla 	 543
# skogen 	 542
# nej 	 539
# frågade 	 535
# gud 	 532
# första 	 525
# åter 	 522
# veta 	 520
# mitt 	 516
# mannen 	 511
# genast 	 508
# stilla 	 506
# hvad 	 505
# tror 	 503
# både 	 502
# framför 	 502
# god 	 500
# gården 	 499
# två 	 498
# emot 	 494
# vägen 	 493
# gammal 	 491
# haft 	 491
# innan 	 491
# ge 	 489
# folk 	 489
# talade 	 488
# ifrån 	 485
# ändå 	 482
# låta 	 481
# fru 	 477
# sätt 	 475
# tro 	 474
# litet 	 473
# ute 	 471
# väg 	 469
# ögonen 	 467
# bra 	 466
# borta 	 464
# all 	 460
# gösta 	 460
# satte 	 459
# alltid 	 458
# heller 	 455
# sådant 	 453
# bättre 	 453
# svarade 	 450
# tänka 	 448
# tiden 	 444
# ögon 	 442
# mellan 	 441
# unga 	 441
# glad 	 436
# redan 	 434
# nästan 	 433
# dagen 	 431
# stå 	 431
# hålla 	 424
# trodde 	 423
# blef 	 423
# kommo 	 421
# inne 	 419
# hört 	 417
# gott 	 417
# bo 	 411
# förstod 	 410
# lade 	 409
# sagt 	 409
# långa 	 406
# vände 	 406
# hand 	 405
# kunnat 	 405
# finns 	 404
# visst 	 403
# steg 	 398
# rädd 	 396
# vore 	 390
# ropade 	 389
# förbi 	 388
# enda 	 387
# lika 	 383
# förstå 	 380
# förr 	 376
# ty 	 374
# marken 	 374
# hustru 	 374
# äro 	 371
# stort 	 370
# riktigt 	 370
# ned 	 369
# ända 	 369
# längre 	 367
# står 	 366
# världen 	 363
# liv 	 362
# nytt 	 359
# människa 	 358
# varför 	 358
# din 	 356
# uppe 	 356
# barnen 	 356
# gör 	 355
# förrän 	 355
# dock 	 354
# bland 	 352
# fara 	 352
# först 	 347
# endast 	 345
# sven 	 343
# dess 	 342
# tycktes 	 341
# lång 	 340
# visa 	 336
# karin 	 336
# lät 	 335
# ögonblick 	 331
# död 	 330
# reste 	 326
# röst 	 325
# tyst 	 325
# måtte 	 324
# fråga 	 324
# sist 	 323
# land 	 322
# lätt 	 322
# förut 	 320
# flickan 	 320
# sitta 	 319
# liksom 	 318
# kyrkan 	 318
# skull 	 318
# resa 	 317
# vår 	 317
# bredvid 	 317
# dit 	 316
# borde 	 316
# flera 	 315
# slut 	 315
# handen 	 309
# nästa 	 308
# hustrun 	 303
# stugan 	 302
# tänker 	 301
# ligger 	 301
# dörren 	 300
# klara 	 300
# vildgässen 	 299
# vilja 	 299
# ekeby 	 298
# for 	 297
# hjälpa 	 297
# natten 	 297
# fall 	 295
# svårt 	 295
# glädje 	 294
# huvudet 	 294
# nere 	 293
# ansikte 	 293
# ena 	 293
# velat 	 292
# ensam 	 292
# hemma 	 291
# högt 	 290
# drog 	 289
# vem 	 289
# intet 	 289
# brukade 	 287
# akka 	 287
# gav 	 286
# stanna 	 286
# följa 	 285
# fast 	 285
# slog 	 284
# arbete 	 284
# detsamma 	 282
# guds 	 280
# stark 	 279
# jorden 	 277
# tycker 	 277
# landet 	 277
# därpå 	 277
# sigrun 	 277
# sista 	 276
# förstår 	 275
# opp 	 275
# märkte 	 272
# såsom 	 271
# kattrinna 	 271
# lagerlöf 	 270
# stannade 	 270
# varje 	 269
# människorna 	 267
# reda 	 266
# utanför 	 266
# undan 	 265
# mina 	 263
# tre 	 262
# sorg 	 262
# halfvor 	 262
# prästen 	 261
# hit 	 260
# livet 	 259
# nära 	 259
# framåt 	 258
# sågo 	 257
# natt 	 256
# hus 	 255
# sätta 	 254
# främmande 	 253
# lotta 	 252
# vänta 	 251
# dagar 	 251
# tagit 	 249
# vita 	 248
# stodo 	 247
# hjälp 	 246
# kärlek 	 246
# plats 	 244
# goda 	 244
# sitter 	 242
# händer 	 242
# rum 	 242
# kastade 	 240
# tankar 	 239
# inga 	 239
# barnet 	 239
# gången 	 238
# bakom 	 238
# händerna 	 238
# bar 	 237
# hästen 	 237
# gärna 	 235
# följde 	 234
# finna 	 233
# gånger 	 233
# knappt 	 233
# gamle 	 233
# mamsell 	 233
# elversson 	 233
# sjön 	 232
# ligga 	 232
# varken 	 231
# alls 	 229
# grevinnan 	 229
# gingo 	 228
# vackert 	 228
# säkert 	 228
# morgon 	 228
# blifvit 	 228
# ihop 	 227
# falla 	 227
# tänkt 	 226
# försökte 	 224
# egen 	 224
# väntade 	 223
# illa 	 223
# fastän 	 222
# hör 	 222
# kyrkoherden 	 222
# ens 	 221
# te 	 220
# lägga 	 220
# tills 	 220
# vatten 	 219
# vidare 	 218
# föll 	 217
# gård 	 217
# tänk 	 216
# vattnet 	 216
# gulla 	 216
# ingrid 	 215
# dö 	 214
# vackra 	 214
# lyfte 	 213
# sådana 	 213
# folket 	 213
# rummet 	 211
# kväll 	 210
# herr 	 210
# leva 	 210
# döda 	 209
# vacker 	 209
# ibland 	 207
# ung 	 207
# jerusalem 	 207
# ihåg 	 206
# båda 	 206
# makt 	 206
# början 	 205
# sak 	 205
# saken 	 205
# anna 	 205
# sökte 	 204
# känna 	 203
# håll 	 202
# herre 	 202
# hjärta 	 201
# sprang 	 201
# bära 	 201
# strax 	 201
# huset 	 201
# bad 	 200
# alltjämt 	 200
# svarta 	 199
# själva 	 199
# höga 	 199
# själf 	 199
# bäst 	 198
# barbro 	 198
# sidan 	 197
# föra 	 197
# inom 	 197
# älskade 	 197
# berätta 	 197
# staden 	 196
# gubben 	 196
# mårbacka 	 194
# lust 	 193
# lågo 	 192
# undrade 	 192
# berling 	 192
# sutto 	 191
# varandra 	 191
# låt 	 191
# havet 	 191
# lycka 	 190
# blevo 	 190
# rätta 	 190
# ansiktet 	 189
# prosten 	 189
# bodde 	 188
# söka 	 188
# stället 	 187
# lille 	 187
# slå 	 186
# vart 	 186
# bästa 	 186
# blott 	 186
# fortfor 	 185
# karl 	 184
# skyndade 	 184
# berättade 	 184
# luften 	 183
# jo 	 182
# ställe 	 181
# löjtnanten 	 181
# fann 	 180
# äntligen 	 179
# kvällen 	 179
# må 	 179
# hög 	 178
# stått 	 178
# talat 	 178
# denne 	 177
# namn 	 177
# majorskan 	 177
# möjligt 	 176
# tunga 	 175
# igenom 	 175
# gåskarlen 	 175
# fattiga 	 175
# visade 	 175
# mest 	 174
# kavaljererna 	 174
# verkligen 	 173
# bordet 	 172
# lämna 	 172
# glada 	 171
# arbetet 	 171
# omöjligt 	 171
# läsa 	 168
# behövde 	 168
# hastigt 	 168
# mat 	 168
# mycken 	 168
# nya 	 168
# röda 	 167
# vända 	 166
# rörde 	 166
# karlen 	 166
# full 	 165
# känner 	 165
# fingo 	 165
# lära 	 164
# lov 	 162
# sant 	 161
# före 	 161
# del 	 161
# knappast 	 160
# ställa 	 159
# skola 	 158
# syntes 	 158
# tar 	 158
# ljus 	 157
# ro 	 157
# lugn 	 157
# sonen 	 156
# vänner 	 156
# vän 	 155
# mening 	 155
# pengar 	 155
# o 	 155
# nå 	 154
# runt 	 154
# mera 	 154
# hängde 	 153
# äta 	 152
# eftersom 	 152
# vågade 	 152
# berg 	 151
# golvet 	 151
# förde 	 151
# gumman 	 151
# större 	 150
# ont 	 150
# skaffa 	 150
# suttit 	 150
# lars 	 150
# sjuk 	 149
# löjtnant 	 149
# mej 	 148
# öppna 	 147
# själ 	 146
# kommen 	 146
# svara 	 146
# solen 	 146
# kvinnan 	 146
# tätt 	 145
# färdig 	 145
# hel 	 145
# håller 	 145
# sättet 	 145
# ofta 	 144
# året 	 143
# djupt 	 143
# smula 	 143
# ack 	 142
# svart 	 142
# rösten 	 142
# fortsatte 	 142
# trappan 	 142
# nyss 	 141
# mörka 	 141
# vandrade 	 141
# karr 	 141
# rent 	 140
# gifta 	 140
# samman 	 140
# träd 	 140
# märkvärdigt 	 140
# spela 	 139
# vilken 	 139
# huvud 	 139
# syster 	 139
# helst 	 138
# någonsin 	 138
# olycka 	 137
# alltsammans 	 137
# kasta 	 137
# uppför 	 137
# ditt 	 137
# allra 	 136
# kring 	 136
# syn 	 136
# sakta 	 136
# hunnit 	 136
# börjat 	 136
# heliga 	 136
# talar 	 136
# blick 	 135
# största 	 135
# sköna 	 135
# fullt 	 134
# lycklig 	 134
# erik 	 134
# hördes 	 133
# skrattade 	 133
# döden 	 133
# nöjd 	 133
# ställde 	 132
# stranden 	 132
# väntat 	 132
# fattig 	 132
# dotter 	 132
# uppåt 	 131
# stående 	 131
# utför 	 131
# män 	 131
# ond 	 130
# finnas 	 130
# arbeta 	 130
# lagt 	 130
# eget 	 130
# marianne 	 130
# sten 	 129
# rädda 	 129
# ny 	 129
# ihjäl 	 129
# taga 	 129
# gråta 	 129
# kajsa 	 129
# sova 	 128
# klart 	 128
# synd 	 128
# bror 	 128
# gossen 	 128
# di 	 128
# kära 	 127
# son 	 127
# kläder 	 127
# eld 	 126
# mindre 	 126
# bonden 	 126
# behöver 	 125
# funnit 	 125
# besynnerligt 	 125
# låtit 	 125
# röra 	 124
# låter 	 124
# stackars 	 124
# gordon 	 124
# djur 	 123
# råkat 	 123
# hafva 	 123
# hellgum 	 123
# mrs 	 123
# maurits 	 123
# fönstret 	 122
# rest 	 122
# hände 	 122
# kvinna 	 122
# tydligt 	 121
# ryckte 	 121
# rörelse 	 121
# lovisa 	 121
# ordning 	 120
# känt 	 120
# socknen 	 120
# förra 	 119
# annars 	 119
# öppnade 	 119
# förfärligt 	 119
# foro 	 119
# vilda 	 119
# starka 	 119
# börja 	 119
# börjar 	 119
# blommor 	 119
# undrar 	 119
# tal 	 119
# höllo 	 118
# läste 	 118
# försöka 	 118
# kvinnor 	 118
# an 	 118
# modern 	 118
# orden 	 117
# lämnade 	 117
# hjärtat 	 117
# kapten 	 117
# därmed 	 116
# sträckte 	 116
# råd 	 116
# tanken 	 115
# gett 	 115
# grät 	 115
# ämnade 	 114
# tungt 	 114
# vägar 	 114
# lisa 	 114
# kort 	 113
# finge 	 113
# minsta 	 113
# tack 	 113
# kalla 	 113
# smirre 	 113
# grå 	 113
# köket 	 113
# dina 	 113
# fri 	 112
# storm 	 112
# stycke 	 112
# stolt 	 112
# legat 	 112
# gift 	 112
# stad 	 111
# morgonen 	 111
# vandra 	 111
# gröna 	 111
# kyrka 	 111
# tycka 	 111
# stuga 	 111
# fadern 	 111
# dä 	 111
# kolonien 	 111
# tummetott 	 110
# jaså 	 110
# likaså 	 110
# våra 	 110
# hushållerskan 	 110
# roligt 	 109
# vila 	 108
# mod 	 108
# ägde 	 108
# hår 	 108
# mängd 	 108
# förstås 	 107
# funnos 	 107
# kistan 	 107
# häst 	 107
# be 	 107
# hållit 	 106
# stånd 	 106
# slagit 	 106
# värre 	 106
# riktig 	 105
# svar 	 105
# armen 	 105
# hede 	 105
# joel 	 105
# stirrade 	 104
# menar 	 104
# slag 	 103
# bär 	 103
# sängen 	 103
# lif 	 103
# ingmarsgården 	 103
# bud 	 102
# säker 	 102
# levde 	 102
# orätt 	 102
# inför 	 102
# björn 	 102
# dra 	 101
# fart 	 101
# utom 	 101
# vrede 	 101
# åtminstone 	 100
# gässen 	 100
# vaknade 	 100
# allting 	 100
# höjde 	 100
# fort 	 100
# vanligt 	 100
# vintern 	 100
# brukar 	 100
# trott 	 100
# sjunga 	 100
# hvarför 	 100
# himlen 	 99
# våren 	 99
# träden 	 99
# blickar 	 98
# vit 	 98
# vinden 	 98
# körde 	 98
# knä 	 98
# skrolycka 	 98
# nino 	 98
# norr 	 97
# råkade 	 97
# somliga 	 97
# hette 	 97
# märka 	 97
# fönster 	 97
# slags 	 97
# brev 	 97
# säg 	 96
# sida 	 96
# växte 	 96
# lyssnade 	 96
# viss 	 96
# arbetade 	 96
# sent 	 96
# jord 	 95
# springa 	 95
# lik 	 95
# rakt 	 95
# kraft 	 95
# långsamt 	 95
# togo 	 95
# sov 	 95
# måst 	 95
# spelade 	 95
# ära 	 95
# älska 	 95
# jungfru 	 95
# sjönk 	 94
# vanliga 	 94
# breda 	 94
# dröjde 	 94
# hårt 	 94
# önskade 	 94
# ryggen 	 93
# ängslan 	 93
# raskt 	 93
# återigen 	 93
# vida 	 93
# därefter 	 93
# historia 	 93
# tjänare 	 93
# översten 	 93
# tårar 	 92
# ångest 	 92
# naturligtvis 	 92
# råka 	 92
# flytta 	 92
# tysta 	 92
# sköt 	 92
# släden 	 92
# gammalt 	 91
# kropp 	 91
# röd 	 91
# hälsa 	 91
# fyra 	 91
# trädgården 	 91
# sjuka 	 91
# leende 	 91
# skolmästarn 	 91
# skog 	 90
# stiga 	 90
# lyste 	 90
# isen 	 90
# ger 	 90
# fem 	 90
# egna 	 90
# hvarje 	 90
# godt 	 90
# sända 	 89
# unge 	 89
# ljusa 	 89
# bygga 	 89
# fina 	 89
# frun 	 89
# dom 	 89
# framme 	 88
# dansa 	 88
# flyga 	 88
# fötter 	 88
# trött 	 88
# böjde 	 88
# berget 	 88
# längtan 	 88
# sköta 	 88
# bergen 	 88
# klockan 	 88
# präst 	 88
# klement 	 88
# brita 	 88
# hedman 	 88
# stina 	 88
# sej 	 88
# nils 	 87
# dar 	 87
# lämnat 	 87
# förvånad 	 87
# skakade 	 87
# ropa 	 87
# hundra 	 87
# rik 	 87
# behöva 	 87
# ständigt 	 87
# onda 	 87
# elden 	 87
# bengt 	 87
# led 	 86
# undra 	 86
# talas 	 86
# utmed 	 86
# märke 	 86
# förmå 	 86
# smala 	 86
# plötsligen 	 86
# tanke 	 86
# hemmet 	 86
# örnen 	 86
# kungen 	 86
# timmar 	 85
# farit 	 85
# skada 	 85
# överallt 	 85
# närmare 	 85
# mötte 	 85
# bjuda 	 85
# bröd 	 85
# midt 	 85
# back 	 85
# värmland 	 84
# föräldrar 	 84
# föräldrarna 	 84
# fallit 	 84
# sommaren 	 84
# behålla 	 84
# sällskap 	 84
# hunden 	 84
# patron 	 84
# allvar 	 83
# klädd 	 83
# underligt 	 83
# munnen 	 83
# djup 	 83
# lärt 	 83
# bönderna 	 83
# flyttade 	 82
# tillsammans 	 82
# bred 	 82
# stenar 	 82
# hämta 	 82
# köpa 	 82
# frågar 	 82
# prästgården 	 82
# hvarandra 	 82
# ingmarsson 	 82
# armarna 	 81
# skratta 	 81
# åsa 	 81
# resan 	 81
# mörk 	 81
# inåt 	 81
# vind 	 81
# kallade 	 81
# landsvägen 	 81
# dog 	 81
# hvem 	 81
# blefvo 	 81
# himmelen 	 80
# minns 	 80
# tung 	 80
# ängslig 	 80
# hända 	 80
# mats 	 80
# fred 	 80
# glömt 	 80
# klok 	 80
# mörkt 	 80
# söder 	 80
# sen 	 80
# vilka 	 80
# menade 	 80
# jarro 	 80
# båten 	 80
# lefva 	 80
# sigurd 	 80
# va 	 80
# vitt 	 79
# vars 	 79
# gående 	 79
# betraktade 	 79
# kvinnorna 	 79
# lugnt 	 79
# lyfta 	 79
# tankarna 	 79
# skriva 	 79
# hvar 	 79
# lär 	 78
# hjälpte 	 78
# flög 	 78
# heter 	 78
# svarar 	 78
# plötsligt 	 78
# karlarna 	 78
# även 	 78
# egentligen 	 78
# nåd 	 78
# ock 	 78
# sintram 	 78
# onkel 	 78
# stockholm 	 77
# olycklig 	 77
# trakten 	 77
# emellertid 	 77
# kastat 	 77
# hellre 	 77
# tecken 	 77
# bruk 	 77
# andre 	 77
# efteråt 	 77
# ändtligen 	 77
# sjö 	 76
# burit 	 76
# håret 	 76
# rusade 	 76
# skrek 	 76
# slippa 	 76
# tåget 	 76
# dagarna 	 76
# låga 	 76
# bataki 	 76
# fel 	 76
# tak 	 76
# hästar 	 76
# flicka 	 76
# hufvudet 	 76
# gunhild 	 76
# rad 	 75
# noga 	 75
# väntar 	 75
# flögo 	 75
# hösten 	 75
# gråa 	 75
# mörkret 	 75
# n 	 75
# svartsjö 	 75
# beerencreutz 	 75
# ganska 	 74
# lös 	 74
# försök 	 74
# fördenskull 	 74
# kyrkogården 	 74
# dunfin 	 74
# levande 	 73
# hänt 	 73
# vingarna 	 73
# åstad 	 73
# vek 	 73
# akt 	 73
# kaffe 	 73
# hästarna 	 73
# hård 	 72
# snön 	 72
# tyckt 	 72
# bekymmer 	 72
# slår 	 72
# funnits 	 72
# hårda 	 72
# platsen 	 72
# tåla 	 72
# gråfäll 	 72
# bord 	 72
# dej 	 72
# eljest 	 71
# glömma 	 71
# intill 	 71
# vetat 	 71
# kroppen 	 71
# ske 	 71
# vingar 	 70
# märkt 	 70
# blå 	 70
# likt 	 70
# glömde 	 70
# värsta 	 70
# hann 	 70
# store 	 70
# bruka 	 70
# skratt 	 70
# alltså 	 70
# tvungen 	 70
# högre 	 70
# gatan 	 70
# dragit 	 70
# därifrån 	 70
# räckte 	 70
# vred 	 70
# dött 	 70
# vårt 	 69
# neråt 	 69
# sätter 	 69
# frisk 	 69
# per 	 69
# krafter 	 69
# stack 	 69
# grep 	 69
# starkt 	 69
# tag 	 69
# dricka 	 69
# nöd 	 69
# längtade 	 69
# slätten 	 69
# visat 	 69
# strid 	 69
# tusen 	 69
# fulla 	 69
# oro 	 69
# förstånd 	 69
# häftigt 	 69
# bor 	 68
# rygg 	 68
# husbonden 	 68
# närheten 	 68
# borg 	 68
# timme 	 68
# porten 	 68
# ton 	 68
# läpparna 	 68
# farväl 	 68
# kärleken 	 68
# tomten 	 67
# ställt 	 67
# östra 	 67
# sänkte 	 67
# flesta 	 67
# ting 	 67
# arm 	 67
# taket 	 67
# möta 	 67
# fält 	 67
# sommar 	 67
# reser 	 67
# fåglar 	 67
# fört 	 67
# strök 	 67
# pannan 	 67
# elände 	 67
# älven 	 67
# älskar 	 67
# runtom 	 67
# holgersson 	 66
# locka 	 66
# störtade 	 66
# tjänst 	 66
# föreföll 	 66
# utbrast 	 66
# icke 	 66
# armar 	 66
# vagnen 	 66
# lill 	 66
# socken 	 65
# komme 	 65
# gåskarl 	 65
# lek 	 65
# laga 	 65
# ber 	 65
# ensamma 	 65
# skynda 	 65
# orolig 	 65
# öster 	 65
# djupa 	 65
# befann 	 65
# sände 	 65
# vilket 	 65
# maja 	 65
# studenten 	 65
# jungfrun 	 65
# ingmars 	 65
# bedja 	 64
# svängde 	 64
# ögonblicket 	 64
# gula 	 64
# växa 	 64
# säng 	 64
# räv 	 64
# hopp 	 64
# tredje 	 64
# våga 	 64
# resande 	 64
# skönhet 	 64
# dalen 	 64
# bryggan 	 64
# strålande 	 64
# förstugan 	 64
# livets 	 64
# fiolen 	 64
# kavaljerer 	 64
# märta 	 64
# korna 	 63
# smög 	 63
# akta 	 63
# sjöng 	 63
# era 	 63
# karlar 	 63
# drogo 	 63
# djuren 	 63
# öde 	 63
# tacka 	 63
# svåra 	 63
# stol 	 63
# småningom 	 62
# begripa 	 62
# levat 	 62
# vågat 	 62
# slogo 	 62
# vandring 	 62
# löpte 	 62
# förtvivlan 	 62
# draga 	 62
# korta 	 62
# släkt 	 62
# jämt 	 62
# teg 	 62
# halsen 	 61
# spisen 	 61
# väggen 	 61
# värld 	 61
# vänligt 	 61
# alltsedan 	 61
# brydde 	 61
# mången 	 61
# sönder 	 61
# viskade 	 61
# fot 	 61
# lagården 	 61
# skön 	 61
# läppar 	 61
# dörrn 	 61
# gaf 	 61
# na 	 61
# titta 	 60
# förmådde 	 60
# följt 	 60
# fortsätta 	 60
# fria 	 60
# svag 	 60
# frågat 	 60
# sju 	 60
# slutat 	 60
# lutade 	 60
# bröt 	 60
# foten 	 60
# kung 	 60
# äfven 	 60
# boken 	 59
# trängde 	 59
# lyssna 	 59
# mark 	 59
# stackare 	 59
# åker 	 59
# fattade 	 59
# köra 	 59
# farligt 	 59
# lever 	 59
# väster 	 59
# johan 	 59
# baram 	 59
# skåne 	 58
# blad 	 58
# torra 	 58
# öppen 	 58
# omkull 	 58
# begära 	 58
# räven 	 58
# senare 	 58
# bro 	 58
# bott 	 58
# tider 	 58
# hittills 	 58
# färdiga 	 58
# kall 	 58
# blod 	 58
# saker 	 58
# kirstine 	 58
# skjuta 	 57
# hemifrån 	 57
# mörker 	 57
# dåligt 	 57
# äga 	 57
# gårdsplanen 	 57
# rika 	 57
# väggar 	 57
# ben 	 57
# numera 	 57
# kär 	 57
# ön 	 57
# tårarna 	 57
# ånej 	 57
# smålog 	 57
# gorgo 	 57
# dottern 	 57
# majoren 	 57
# klockarn 	 57
# teodor 	 57
# sverige 	 56
# bryta 	 56
# liggande 	 56
# lyckades 	 56
# stötte 	 56
# dans 	 56
# fly 	 56
# lyckats 	 56
# väggarna 	 56
# väldiga 	 56
# tvinga 	 56
# guld 	 56
# bjöd 	 56
# någonting 	 56
# önskar 	 56
# veckor 	 56
# älskat 	 56
# björnen 	 56
# graven 	 56
# tokig 	 56
# svår 	 55
# fin 	 55
# sluta 	 55
# luft 	 55
# rop 	 55
# ledde 	 55
# verk 	 55
# sanning 	 55
# sittande 	 55
# tordes 	 55
# grav 	 55
# ställen 	 55
# visserligen 	 55
# nytta 	 55
# korpen 	 55
# mun 	 55
# båt 	 55
# augusti 	 55
# förlorat 	 55
# konstantin 	 55
# klagade 	 54
# skolan 	 54
# vild 	 54
# mors 	 54
# tittade 	 54
# rycka 	 54
# åkrar 	 54
# färden 	 54
# därhemma 	 54
# präktiga 	 54
# glans 	 54
# påminde 	 54
# tränga 	 54
# stannar 	 54
# tjäna 	 54
# hållet 	 54
# fåglarna 	 54
# mild 	 54
# ombord 	 54
# himmel 	 54
# brukspatronen 	 54
# bok 	 54
# kärran 	 54
# sången 	 54
# fint 	 54
# stafva 	 54
# besvär 	 53
# hoppade 	 53
# hund 	 53
# stannat 	 53
# hast 	 53
# täta 	 53
# driva 	 53
# åkte 	 53
# stig 	 53
# innanför 	 53
# skuld 	 53
# vaken 	 53
# tio 	 53
# tiga 	 53
# sjukdom 	 53
# stunden 	 53
# muren 	 53
# vandrande 	 53
# ifall 	 53
# stenen 	 53
# historien 	 53
# åka 	 53
# sanningen 	 53
# prästfrun 	 53
# kriget 	 53
# lifvet 	 53
# selma 	 52
# pojke 	 52
# alltför 	 52
# tur 	 52
# dröm 	 52
# skräck 	 52
# leka 	 52
# bredde 	 52
# höjden 	 52
# eftermiddagen 	 52
# svarat 	 52
# lön 	 52
# skara 	 52
# sömn 	 52
# straff 	 52
# band 	 52
# ansikten 	 52
# gårdar 	 52
# stämma 	 52
# olive 	 52
# lennart 	 52
# gunnarsson 	 52
# sång 	 51
# bleve 	 51
# nakna 	 51
# köld 	 51
# kallar 	 51
# vågar 	 51
# vägkanten 	 51
# bröllop 	 51
# tolv 	 51
# hjärtan 	 51
# ljung 	 51
# drängen 	 51
# ropar 	 51
# förfärliga 	 51
# stundom 	 51
# anders 	 51
# dohna 	 51
# birger 	 51
# pascha 	 51
# arild 	 51
# teresa 	 51
# hinna 	 50
# västra 	 50
# parveln 	 50
# meningen 	 50
# ert 	 50
# van 	 50
# ä 	 50
# bröstet 	 50
# snö 	 50
# ämnar 	 50
# förstått 	 50
# slutet 	 50
# försökt 	 50
# mil 	 50
# inre 	 50
# skydd 	 50
# givit 	 50
# ljust 	 50
# minne 	 50
# sken 	 50
# försvann 	 50
# suckade 	 50
# männen 	 50
# grafven 	 50
# fröken 	 50
# marie 	 50
# fågel 	 49
# svenska 	 49
# blickarna 	 49
# förfärlig 	 49
# branta 	 49
# lyckan 	 49
# varmt 	 49
# nedanför 	 49
# nådde 	 49
# rådde 	 49
# strömmade 	 49
# färd 	 49
# vinna 	 49
# bryr 	 49
# utseende 	 49
# heder 	 49
# rosor 	 49
# lägger 	 49
# järn 	 49
# därinne 	 49
# dimman 	 49
# riktiga 	 49
# kristus 	 49
# matmodern 	 49
# bett 	 49
# lyckliga 	 49
# skrivit 	 49
# mycke 	 49
# samt 	 49
# gabriel 	 49
# grönt 	 48
# drag 	 48
# ungdom 	 48
# nickade 	 48
# ola 	 48
# märktes 	 48
# närmast 	 48
# dörr 	 48
# yttersta 	 48
# kallas 	 48
# samlade 	 48
# ljöd 	 48
# åtta 	 48
# jätten 	 48
# blanka 	 48
# härifrån 	 48
# härlighet 	 48
# blek 	 48
# lucia 	 48
# hvilken 	 48
# krus 	 48
# eljas 	 48
# jofrid 	 48
# särdeles 	 47
# kröp 	 47
# präktig 	 47
# lyckas 	 47
# väder 	 47
# mårten 	 47
# faller 	 47
# förvånade 	 47
# slott 	 47
# röster 	 47
# lugna 	 47
# människors 	 47
# delen 	 47
# oppe 	 47
# sol 	 47
# glädjen 	 47
# passade 	 47
# vård 	 47
# törs 	 47
# ärende 	 47
# ljuset 	 47
# julius 	 47
# blomgren 	 47
# hvilka 	 47
# hårdt 	 47
# säjer 	 47
# karlstad 	 47
# ve 	 47
# söndag 	 46
# förvåning 	 46
# vilt 	 46
# ämnat 	 46
# fisk 	 46
# frågor 	 46
# vänster 	 46
# sex 	 46
# fruktan 	 46
# ungefär 	 46
# härliga 	 46
# gille 	 46
# krig 	 46
# sörja 	 46
# räkna 	 46
# spelar 	 46
# rullade 	 46
# kulle 	 46
# klar 	 46
# hjälpt 	 46
# kråkorna 	 46
# sannerligen 	 46
# hälsade 	 46
# vågorna 	 46
# tillräckligt 	 46
# flickorna 	 46
# själfva 	 46
# hvita 	 46
# åv 	 46
# blicken 	 45
# kor 	 45
# bedrövad 	 45
# sprungo 	 45
# solskenet 	 45
# språng 	 45
# följer 	 45
# fötterna 	 45
# fatt 	 45
# förklara 	 45
# störa 	 45
# plockade 	 45
# vanlig 	 45
# mäktig 	 45
# trädgård 	 45
# hök 	 45
# berättat 	 45
# ringa 	 45
# kämpade 	 45
# spelat 	 45
# förlåta 	 45
# ful 	 45
# tunna 	 45
# log 	 45
# upprepade 	 45
# cesar 	 45
# sorgen 	 45
# knäppte 	 45
# läst 	 45
# lite 	 45
# anklagade 	 45
# liljecrona 	 45
# eberhard 	 45
# stjärnhök 	 45
# tönne 	 45
# ruben 	 45
# öron 	 44
# varenda 	 44
# spår 	 44
# förargåsen 	 44
# kastar 	 44
# sämre 	 44
# åkrarna 	 44
# åkern 	 44
# tillfälle 	 44
# skämt 	 44
# sökt 	 44
# runda 	 44
# skedde 	 44
# envar 	 44
# drar 	 44
# visar 	 44
# desto 	 44
# botten 	 44
# hatten 	 44
# komna 	 44
# allesammans 	 44
# sälja 	 44
# trösta 	 44
# arbetat 	 44
# brodern 	 44
# skam 	 44
# boningshuset 	 44
# barmhärtighet 	 44
# pengarna 	 44
# rike 	 44
# någe 	 44
# behöfde 	 44
# henrik 	 44
# faster 	 44
# regementsskrivarn 	 44
# tord 	 44
# lida 	 43
# försvara 	 43
# fars 	 43
# ovanligt 	 43
# jämnt 	 43
# däremot 	 43
# leta 	 43
# äldsta 	 43
# hörn 	 43
# hitta 	 43
# begav 	 43
# mindes 	 43
# skarpa 	 43
# mäktiga 	 43
# sidor 	 43
# herrar 	 43
# rök 	 43
# forna 	 43
# skrik 	 43
# vänder 	 43
# sällan 	 43
# olyckan 	 43
# glatt 	 43
# mjuka 	 43
# lätta 	 43
# glas 	 43
# ljud 	 43
# arbetare 	 43
# bönder 	 43
# amerika 	 43
# frid 	 43
# grinden 	 43
# björnfar 	 43
# herrn 	 43
# bygden 	 43
# farmor 	 43
# salen 	 43
# broby 	 43
# ruster 	 43
# kolonisterna 	 43
# mä 	 43
# böner 	 42
# blåa 	 42
# brinnande 	 42
# värd 	 42
# slöt 	 42
# beslöt 	 42
# smal 	 42
# mittpå 	 42
# slängde 	 42
# flugit 	 42
# hål 	 42
# pass 	 42
# höger 	 42
# jaga 	 42
# kändes 	 42
# besynnerlig 	 42
# skaran 	 42
# egendom 	 42
# vana 	 42
# välkommen 	 42
# dessutom 	 42
# känsla 	 42
# småland 	 42
# märker 	 42
# undgå 	 42
# förskräckt 	 42
# dålig 	 42
# samtalet 	 42
# skötte 	 42
# storstugan 	 42
# gråt 	 42
# tjugu 	 42
# trädde 	 42
# gåva 	 42
# hånger 	 42
# dansen 	 42
# miss 	 42
# hvarken 	 42
# säja 	 42
# börje 	 42
# sträng 	 41
# somnade 	 41
# hemskt 	 41
# snäll 	 41
# tomma 	 41
# gårdarna 	 41
# tryckte 	 41
# lita 	 41
# trots 	 41
# förhöll 	 41
# närmade 	 41
# byggde 	 41
# äventyr 	 41
# vinter 	 41
# förlora 	 41
# mött 	 41
# stolta 	 41
# strida 	 41
# fyllde 	 41
# väcka 	 41
# märkvärdig 	 41
# klagan 	 41
# gäster 	 41
# varelse 	 41
# äldre 	 41
# böcker 	 41
# därborta 	 41
# åkande 	 41
# brasan 	 41
# skrev 	 41
# lidande 	 41
# bergsrådinnan 	 41
# kavaljersflygeln 	 41
# minnet 	 40
# barnets 	 40
# skott 	 40
# tröskeln 	 40
# rött 	 40
# red 	 40
# föllo 	 40
# vuxit 	 40
# katten 	 40
# utåt 	 40
# olika 	 40
# flock 	 40
# dansade 	 40
# skogsbrynet 	 40
# kallt 	 40
# gåsapiga 	 40
# tjocka 	 40
# hjälplös 	 40
# inpå 	 40
# regn 	 40
# kristian 	 40
# skickat 	 40
# mål 	 40
# farlig 	 40
# panna 	 40
# finner 	 40
# landskapet 	 40
# upphörde 	 40
# smärta 	 40
# utropade 	 40
# längtar 	 40
# sanden 	 40
# begärde 	 40
# sjunka 	 40
# förstöra 	 40
# närmaste 	 40
# vika 	 40
# kon 	 40
# dal 	 40
# döttrar 	 40
# vargarna 	 40
# fiol 	 40
# kysste 	 40
# församlingen 	 40
# gunnar 	 40
# bleka 	 40
# elisabet 	 40
# matts 	 40
# bilden 	 39
# därav 	 39
# blänkte 	 39
# förlorade 	 39
# flocken 	 39
# vildgäss 	 39
# ätit 	 39
# månad 	 39
# bestämt 	 39
# lovat 	 39
# gräset 	 39
# talet 	 39
# flydde 	 39
# lekte 	 39
# bit 	 39
# styrka 	 39
# flyttat 	 39
# märkvärdiga 	 39
# världens 	 39
# doktorn 	 39
# april 	 39
# verket 	 39
# längs 	 39
# farliga 	 39
# darrade 	 39
# lyda 	 39
# rör 	 39
# söker 	 39
# tackade 	 39
# hjälper 	 39
# solsken 	 39
# styra 	 39
# papper 	 39
# värst 	 39
# minnas 	 39
# förklarade 	 39
# mannens 	 39
# snälla 	 39
# löven 	 39
# greven 	 39
# slom 	 39
# askedalarna 	 39
# släppte 	 38
# krypa 	 38
# smyga 	 38
# tidigt 	 38
# färdas 	 38
# störta 	 38
# is 	 38
# hoppas 	 38
# därtill 	 38
# längesedan 	 38
# gömde 	 38
# miste 	 38
# torn 	 38
# trånga 	 38
# fruktade 	 38
# vecka 	 38
# dör 	 38
# hindra 	 38
# väckte 	 38
# månader 	 38
# skogarna 	 38
# hav 	 38
# lysande 	 38
# utbredde 	 38
# bör 	 38
# siden 	 38
# stormen 	 38
# starkare 	 38
# färdigt 	 38
# fatta 	 38
# behöfver 	 38
# ormen 	 38
# dalarna 	 38
# historier 	 38
# handla 	 38
# skrika 	 38
# drömmar 	 38
# drömmen 	 38
# skolhuset 	 38
# vagn 	 38
# ondt 	 38
# rundt 	 38
# eskil 	 38
# grevinna 	 38
# ingmarsdotter 	 38
# ordentligt 	 37
# dum 	 37
# flygande 	 37
# hals 	 37
# herrgård 	 37
# rida 	 37
# stöd 	 37
# bry 	 37
# nacken 	 37
# allihop 	 37
# nått 	 37
# orörlig 	 37
# passa 	 37
# torr 	 37
# öga 	 37
# ägg 	 37
# kallades 	 37
# präktigt 	 37
# skogar 	 37
# brutit 	 37
# husen 	 37
# stängde 	 37
# önska 	 37
# tom 	 37
# klädda 	 37
# rörd 	 37
# stränderna 	 37
# blickade 	 37
# fördes 	 37
# bänken 	 37
# tåkern 	 37
# ene 	 37
# lärde 	 37
# sjukdomen 	 37
# bron 	 37
# järnet 	 37
# larsson 	 37
# lof 	 37
# brännvin 	 37
# wennervik 	 37
# kapitlet 	 37
# sinclaire 	 37
# vandrat 	 36
# nätt 	 36
# kista 	 36
# galet 	 36
# låtsade 	 36
# buro 	 36
# vite 	 36
# sticka 	 36
# vansinnig 	 36
# slutade 	 36
# bestod 	 36
# brådska 	 36
# fundera 	 36
# öppnades 	 36
# härlig 	 36
# högtidligt 	 36
# stänga 	 36
# ägt 	 36
# alltifrån 	 36
# sjöar 	 36
# gled 	 36
# troll 	 36
# mans 	 36
# fyllda 	 36
# vandringen 	 36
# plocka 	 36
# visby 	 36
# grant 	 36
# skett 	 36
# brinna 	 36
# minnen 	 36
# bön 	 36
# jul 	 36
# predika 	 36
# korset 	 36
# tröst 	 36
# heta 	 36
# släde 	 36
# brygghuset 	 36
# lefde 	 36
# tavaststjerna 	 36
# greve 	 36
# wachenfeldt 	 36
# notbindarn 	 36
# läser 	 35
# våld 	 35
# minuter 	 35
# tjock 	 35
# backen 	 35
# granna 	 35
# huvuden 	 35
# spetsen 	 35
# lappland 	 35
# svagt 	 35
# andras 	 35
# välja 	 35
# skönt 	 35
# släpade 	 35
# klättrade 	 35
# skarpt 	 35
# ängsliga 	 35
# häftig 	 35
# fiender 	 35
# förstört 	 35
# skäl 	 35
# vare 	 35
# sekund 	 35
# erkänna 	 35
# flykt 	 35
# humör 	 35
# mur 	 35
# skilja 	 35
# önskat 	 35
# ved 	 35
# förskräckelse 	 35
# stjärnor 	 35
# ungdomen 	 35
# utväg 	 35
# storån 	 35
# vers 	 35
# middag 	 35
# brevet 	 35
# tale 	 35
# bom 	 35
# främst 	 34
# kinder 	 34
# massa 	 34
# lovade 	 34
# tystnade 	 34
# lysa 	 34
# jagade 	 34
# vakna 	 34
# drömt 	 34
# grön 	 34
# fira 	 34
# jämrade 	 34
# förfäran 	 34
# neka 	 34
# råda 	 34
# sålunda 	 34
# inget 	 34
# grova 	 34
# betrakta 	 34
# nätterna 	 34
# klädde 	 34
# berättelse 	 34
# mumlade 	 34
# års 	 34
# krona 	 34
# flickor 	 34
# gifte 	 34
# skrattar 	 34
# ångbåten 	 34
# tron 	 34
# andersson 	 34
# käre 	 34
# von 	 34
# älfven 	 34
# brefvet 	 34
# färg 	 33
# södra 	 33
# klättra 	 33
# tät 	 33
# ordet 	 33
# fasa 	 33
# fritt 	 33
# svårighet 	 33
# nämligen 	 33
# svälta 	 33
# rikt 	 33
# byggt 	 33
# rummen 	 33
# tålamod 	 33
# ångra 	 33
# motstånd 	 33
# räkning 	 33
# funno 	 33
# ivrigt 	 33
# jämna 	 33
# blodet 	 33
# ögat 	 33
# bunden 	 33
# eftermiddag 	 33
# annorlunda 	 33
# naturen 	 33
# torget 	 33
# stränga 	 33
# milda 	 33
# drev 	 33
# äger 	 33
# drömde 	 33
# språkade 	 33
# betala 	 33
# ledsen 	 33
# kullar 	 33
# bonde 	 33
# vänliga 	 33
# silver 	 33
# längta 	 33
# stigit 	 33
# svaret 	 33
# skiljas 	 33
# rätade 	 33
# påminna 	 33
# brukspatron 	 33
# älgen 	 33
# ovanför 	 33
# dödens 	 33
# undrat 	 33
# morbror 	 33
# minst 	 33
# skriver 	 33
# blommorna 	 33
# blifva 	 33
# sjuttonde 	 33
# betsy 	 33
# tomt 	 32
# fjärran 	 32
# avstånd 	 32
# funderade 	 32
# fler 	 32
# benen 	 32
# skrämma 	 32
# farande 	 32
# släppa 	 32
# bladen 	 32
# täckt 	 32
# pekade 	 32
# klaga 	 32
# fånga 	 32
# flöt 	 32
# öra 	 32
# använda 	 32
# hämtade 	 32
# ungarna 	 32
# murar 	 32
# visor 	 32
# hejdade 	 32
# ståtliga 	 32
# besynnerliga 	 32
# mossa 	 32
# spel 	 32
# toppen 	 32
# stegen 	 32
# käppen 	 32
# häpen 	 32
# trygg 	 32
# smaka 	 32
# vuxna 	 32
# stycken 	 32
# kors 	 32
# gömma 	 32
# fattigdom 	 32
# erfor 	 32
# jakt 	 32
# skogvaktaren 	 32
# axel 	 32
# handlat 	 32
# rikedom 	 32
# jordens 	 32
# professorn 	 32
# systrar 	 32
# tystnad 	 32
# låna 	 32
# jesus 	 32
# ande 	 32
# plåga 	 32
# feber 	 32
# döde 	 32
# kusin 	 32
# kevenhüller 	 32
# kristofer 	 32
# själen 	 31
# förmiddagen 	 31
# öppet 	 31
# möttes 	 31
# lättare 	 31
# skydda 	 31
# narr 	 31
# ivrig 	 31
# grenar 	 31
# oupphörligen 	 31
# iver 	 31
# börda 	 31
# oftast 	 31
# storken 	 31
# lynne 	 31
# stiger 	 31
# glädja 	 31
# jämmer 	 31
# fäste 	 31
# träffade 	 31
# räknade 	 31
# muntert 	 31
# brann 	 31
# suck 	 31
# snoken 	 31
# löfte 	 31
# fula 	 31
# kusken 	 31
# grimön 	 31
# kyssa 	 31
# hvart 	 31
# mamma 	 31
# lövens 	 31
# rangela 	 31
# rese 	 31
# brobyprästen 	 31
# kaptenskan 	 31
# jaffa 	 31
# fröjd 	 30
# fjäll 	 30
# stängt 	 30
# predikan 	 30
# hänga 	 30
# fattigt 	 30
# bottnen 	 30
# skreko 	 30
# öronen 	 30
# alltmer 	 30
# raka 	 30
# bruna 	 30
# farten 	 30
# utefter 	 30
# baklänges 	 30
# jägare 	 30
# springande 	 30
# förstodo 	 30
# lidit 	 30
# allén 	 30
# föda 	 30
# sjöngo 	 30
# arma 	 30
# behagade 	 30
# nyheter 	 30
# kämpa 	 30
# missnöjd 	 30
# djupet 	 30
# begär 	 30
# skäret 	 30
# lämnar 	 30
# båtar 	 30
# springer 	 30
# liknade 	 30
# yr 	 30
# önskan 	 30
# vrå 	 30
# värme 	 30
# sjunkit 	 30
# ile 	 30
# tigga 	 30
# minnes 	 30
# fylld 	 30
# klocka 	 30
# boskap 	 30
# lösa 	 30
# väntan 	 30
# trädgårdsmästaren 	 30
# hädanefter 	 30
# husmodern 	 30
# uttryck 	 30
# kläderna 	 30
# prostgården 	 30
# upprörd 	 30
# herrarna 	 30
# friska 	 30
# högsta 	 30
# husbonde 	 30
# fingrarna 	 30
# thala 	 30
# skrifva 	 30
# farbror 	 30
# adjunkten 	 30
# melchior 	 30
# berga 	 30
# ingmarssönerna 	 30
# skolmästarns 	 30
# fanjunkar 	 30
# fromma 	 29
# lyfter 	 29
# syns 	 29
# elak 	 29
# rader 	 29
# näsan 	 29
# gosse 	 29
# bröst 	 29
# norrut 	 29
# sträcka 	 29
# oroliga 	 29
# möda 	 29
# gripa 	 29
# säd 	 29
# passande 	 29
# byggnader 	 29
# begrep 	 29
# gräs 	 29
# vakta 	 29
# päls 	 29
# kloka 	 29
# sprungit 	 29
# nöja 	 29
# brukat 	 29
# mesta 	 29
# klätt 	 29
# ren 	 29
# svartråttorna 	 29
# kyrkor 	 29
# livs 	 29
# kvistar 	 29
# stenarna 	 29
# vågor 	 29
# skär 	 29
# högst 	 29
# tvärt 	 29
# blyg 	 29
# nöje 	 29
# skicka 	 29
# sover 	 29
# bänk 	 29
# grund 	 29
# upptäckt 	 29
# fult 	 29
# stallet 	 29
# nyckeln 	 29
# brud 	 29
# drömma 	 29
# kvarnen 	 29
# musik 	 29
# hufvud 	 29
# bref 	 29
# pastor 	 29
# kejsarinnan 	 29
# kavaljer 	 29
# himmelens 	 28
# slätt 	 28
# därvid 	 28
# ofantligt 	 28
# nöjda 	 28
# särskilt 	 28
# gammaldags 	 28
# porträtt 	 28
# slita 	 28
# ovan 	 28
# hejda 	 28
# brusade 	 28
# lågt 	 28
# fisken 	 28
# övriga 	 28
# otroligt 	 28
# grann 	 28
# bädd 	 28
# trivas 	 28
# sysslade 	 28
# styrde 	 28
# kanten 	 28
# utmärkt 	 28
# mittunder 	 28
# pigorna 	 28
# uppehåll 	 28
# bittert 	 28
# stigar 	 28
# njuta 	 28
# brunnen 	 28
# kullen 	 28
# synas 	 28
# bjuder 	 28
# orkade 	 28
# vållat 	 28
# ån 	 28
# leder 	 28
# samlat 	 28
# ovillkorligen 	 28
# läto 	 28
# nödvändigt 	 28
# jämn 	 28
# skapa 	 28
# dumt 	 28
# närvarande 	 28
# holmen 	 28
# stoppade 	 28
# göras 	 28
# boskapen 	 28
# öppnat 	 28
# grannarna 	 28
# gäller 	 28
# grubblade 	 28
# nämna 	 28
# släpa 	 28
# ståtlig 	 28
# hälsning 	 28
# backe 	 28
# namnet 	 28
# dels 	 28
# fylla 	 28
# torde 	 28
# sommarn 	 28
# middagen 	 28
# uppmärksamhet 	 28
# skansen 	 28
# fäboden 	 28
# disponenten 	 28
# smedjan 	 28
# lamprecht 	 28
# hat 	 28
# nedåt 	 28
# portugallien 	 28
# biskopen 	 28
# starke 	 28
# breven 	 28
# hop 	 27
# tåg 	 27
# smugit 	 27
# trettio 	 27
# förskräckligt 	 27
# ängar 	 27
# allvarsam 	 27
# svävade 	 27
# kamrater 	 27
# anseende 	 27
# behövdes 	 27
# näbben 	 27
# frågan 	 27
# klor 	 27
# blind 	 27
# trädet 	 27
# uthärda 	 27
# medlidande 	 27
# bondgård 	 27
# besked 	 27
# trötta 	 27
# slutligen 	 27
# fyllt 	 27
# skaffat 	 27
# parken 	 27
# vilade 	 27
# tågade 	 27
# befallde 	 27
# skickade 	 27
# valt 	 27
# kusten 	 27
# vänlig 	 27
# halvt 	 27
# brant 	 27
# regnet 	 27
# dörrar 	 27
# mössan 	 27
# fors 	 27
# möter 	 27
# upphöra 	 27
# stängda 	 27
# vinkade 	 27
# svanorna 	 27
# saknad 	 27
# invid 	 27
# skrämd 	 27
# kala 	 27
# förnämsta 	 27
# däri 	 27
# glömmer 	 27
# vackrare 	 27
# trakt 	 27
# berodde 	 27
# hakan 	 27
# ko 	 27
# längtat 	 27
# eviga 	 27
# fången 	 27
# åren 	 27
# hugga 	 27
# tjänat 	 27
# kör 	 27
# emellan 	 27
# fästa 	 27
# fickan 	 27
# gråter 	 27
# byta 	 27
# fiskaren 	 27
# värde 	 27
# händelser 	 27
# begravningen 	 27
# söndagen 	 27
# föga 	 27
# applum 	 27
# ögonlocken 	 27
# kejsare 	 27
# vin 	 27
# elake 	 27
# ulrika 	 27
# sågen 	 27
# mattsson 	 27
# hafvet 	 27
# prästberg 	 27
# vaka 	 26
# fälla 	 26
# gäss 	 26
# skugga 	 26
# hatt 	 26
# upptagen 	 26
# stolen 	 26
# härmed 	 26
# mista 	 26
# gråtit 	 26
# marknad 	 26
# betyda 	 26
# tämligen 	 26
# brett 	 26
# binda 	 26
# född 	 26
# lägg 	 26
# lustiga 	 26
# frihet 	 26
# behövt 	 26
# tvekan 	 26
# rövare 	 26
# tiggare 	 26
# kråkor 	 26
# beslut 	 26
# blåste 	 26
# synes 	 26
# kullaberg 	 26
# bistå 	 26
# toner 	 26
# vandrare 	 26
# kullarna 	 26
# högg 	 26
# känslor 	 26
# uppstod 	 26
# hälften 	 26
# månskenet 	 26
# nödgas 	 26
# port 	 26
# upphört 	 26
# samla 	 26
# mjukt 	 26
# hållning 	 26
# strålade 	 26
# sörjde 	 26
# motstå 	 26
# kniv 	 26
# bådo 	 26
# skar 	 26
# förgås 	 26
# vänt 	 26
# vägarna 	 26
# mjuk 	 26
# smör 	 26
# söner 	 26
# sönerna 	 26
# förskräckliga 	 26
# uppland 	 26
# säcken 	 26
# bohuslän 	 26
# afton 	 26
# allvarligt 	 26
# fängelset 	 26
# oktober 	 26
# dalkarlen 	 26
# tidningen 	 26
# person 	 26
# julen 	 26
# stenbroträsk 	 26
# hänförelse 	 26
# syner 	 26
# prostdottern 	 26
# själar 	 26
# ifrigt 	 26
# händt 	 26
# pastorn 	 26
# kalas 	 26
# kavaljerernas 	 26
# moster 	 26
# bröllopet 	 26
# löwenborg 	 26
# young 	 26
# raklitz 	 26
# fredrika 	 26
# anne 	 26
# städer 	 25
# rå 	 25
# ondska 	 25
# friskt 	 25
# locket 	 25
# lustigt 	 25
# skor 	 25
# pojkar 	 25
# grått 	 25
# otålig 	 25
# tycks 	 25
# styva 	 25
# dela 	 25
# överge 	 25
# strand 	 25
# kölden 	 25
# täckte 	 25
# nätter 	 25
# pina 	 25
# andan 	 25
# byggnad 	 25
# borgen 	 25
# hindrade 	 25
# framemot 	 25
# brokiga 	 25
# slottet 	 25
# bota 	 25
# pojkarna 	 25
# trogen 	 25
# ermenrich 	 25
# varade 	 25
# klippan 	 25
# rävarna 	 25
# bet 	 25
# oändligt 	 25
# fönstren 	 25
# brusande 	 25
# mötas 	 25
# dimma 	 25
# gräva 	 25
# glänsande 	 25
# väldig 	 25
# skrämt 	 25
# klappade 	 25
# präster 	 25
# alltihop 	 25
# spara 	 25
# matmor 	 25
# färdades 	 25
# dåliga 	 25
# samtal 	 25
# bädden 	 25
# kvällarna 	 25
# drängar 	 25
# vilkas 	 25
# rodde 	 25
# möjlighet 	 25
# prostinnan 	 25
# vuxen 	 25
# kronor 	 25
# systern 	 25
# sjutton 	 25
# västergötland 	 25
# gåvor 	 25
# skänkt 	 25
# sjuke 	 25
# språka 	 25
# munterhet 	 25
# papperet 	 25
# löst 	 25
# åkdon 	 25
# skriker 	 25
# direktören 	 25
# t 	 25
# knöt 	 25
# dansat 	 25
# fader 	 25
# drifva 	 25
# dam 	 25
# kejsarn 	 25
# drottning 	 25
# eva 	 25
# gästerna 	 25
# klockaren 	 25
# don 	 25
# oljoberget 	 25
# ämtervik 	 25
# broström 	 25
# urup 	 25
# dunungen 	 25
# strömmar 	 24
# varm 	 24
# auktionen 	 24
# hemsk 	 24
# tjänade 	 24
# bostad 	 24
# utlandet 	 24
# höja 	 24
# lockat 	 24
# förakt 	 24
# tvärsöver 	 24
# belåten 	 24
# kamrat 	 24
# mottagen 	 24
# stjäla 	 24
# värt 	 24
# förmiddag 	 24
# ansåg 	 24
# mittemot 	 24
# vakt 	 24
# hängande 	 24
# koja 	 24
# rasande 	 24
# by 	 24
# upptäckte 	 24
# snår 	 24
# sänt 	 24
# glimmingehus 	 24
# dystra 	 24
# udde 	 24
# råkar 	 24
# ödsliga 	 24
# blänkande 	 24
# takt 	 24
# backar 	 24
# vildmarken 	 24
# boden 	 24
# synen 	 24
# ström 	 24
# söderut 	 24
# utsikt 	 24
# strängt 	 24
# väckt 	 24
# klokt 	 24
# fåren 	 24
# försöker 	 24
# förtjäna 	 24
# skönaste 	 24
# försvinna 	 24
# landskap 	 24
# hörnet 	 24
# passar 	 24
# gumma 	 24
# släktingar 	 24
# aning 	 24
# tvungna 	 24
# språk 	 24
# hundar 	 24
# förmåga 	 24
# lydde 	 24
# bringa 	 24
# vargar 	 24
# hemvägen 	 24
# ålder 	 24
# granarna 	 24
# bröder 	 24
# mälaren 	 24
# riksdaler 	 24
# förste 	 24
# sinne 	 24
# rykte 	 24
# friheten 	 24
# fyrtio 	 24
# kinderna 	 24
# axlarna 	 24
# ålin 	 24
# stämman 	 24
# lövdala 	 24
# magister 	 24
# silfverbrandt 	 24
# börtsholm 	 24
# gode 	 24
# eriksson 	 24
# vestblad 	 24
# underbara 	 23
# herren 	 23
# höjd 	 23
# längst 	 23
# gärning 	 23
# lyckligt 	 23
# hittat 	 23
# stackaren 	 23
# skaka 	 23
# vartenda 	 23
# strupe 	 23
# strupen 	 23
# makten 	 23
# horn 	 23
# skild 	 23
# underbart 	 22
# sunne 	 22
# sagor 	 22
# träda 	 22
# vänern 	 22
# trygghet 	 22
# offra 	 22
# mistat 	 22
# församling 	 22
# predikstolen 	 22
# olaus 	 22
# edvard 	 22
# naturligt 	 22
# kristna 	 22
# roll 	 22
# körande 	 22
# älskad 	 22
# däck 	 22
# lefvat 	 22
# offer 	 22
# tiggaren 	 22
# major 	 22
# schäsen 	 22
# fredrik 	 22
# riksdagsmannen 	 22
# tims 	 22
# golgata 	 22
# lagerlöfs 	 22
# me 	 22
# nån 	 22
# gullas 	 22
# hemlighet 	 21
# mars 	 21
# fjorton 	 21
# vackraste 	 21
# hönsen 	 21
# sömnen 	 21
# somna 	 21
# brände 	 21
# gömd 	 21
# försona 	 21
# taget 	 21
# undrande 	 21
# tös 	 21
# sjöarna 	 21
# stugorna 	 21
# simma 	 21
# kebnekajse 	 21
# andetag 	 21
# hungrig 	 21
# ordnade 	 21
# flyger 	 21
# gås 	 21
# frukta 	 21
# försvunnen 	 21
# bråttom 	 21
# jakten 	 21
# kammare 	 21
# ungar 	 21
# samlades 	 21
# säkerligen 	 21
# instängd 	 21
# värmen 	 21
# fortare 	 21
# pigor 	 21
# övre 	 21
# stulit 	 21
# mittibland 	 21
# skjuter 	 21
# utsikten 	 21
# midnatt 	 21
# ridande 	 21
# dyster 	 21
# framgång 	 21
# avsikt 	 21
# evigt 	 21
# slutar 	 21
# stugor 	 21
# störtar 	 21
# snarare 	 21
# strömmen 	 21
# styv 	 21
# sund 	 21
# fartyg 	 21
# bilder 	 21
# vilse 	 21
# bildade 	 21
# grunden 	 21
# lagade 	 21
# upprätt 	 21
# pröva 	 21
# ropat 	 21
# betyder 	 21
# kvinnfolk 	 21
# utföra 	 21
# begriper 	 21
# paradiset 	 21
# höst 	 21
# skåda 	 21
# förfärad 	 21
# tacksam 	 21
# stigen 	 21
# låtsa 	 21
# framtid 	 21
# slingrade 	 21
# räddad 	 21
# tänderna 	 21
# larverna 	 21
# mötes 	 21
# högtidlig 	 21
# tända 	 21
# minut 	 21
# välsignelse 	 21
# drack 	 21
# svaga 	 21
# lockar 	 21
# verkliga 	 21
# go 	 21
# maj 	 21
# föras 	 21
# rak 	 21
# träffa 	 21
# sinnet 	 21
# bänkar 	 21
# sy 	 21
# trevnad 	 21
# stel 	 21
# tömmarna 	 21
# drängstugan 	 21
# bänkarna 	 21
# lärarinnan 	 21
# underliga 	 21
# begått 	 21
# brast 	 21
# tiggde 	 21
# småleende 	 21
# oskyldig 	 21
# klänning 	 21
# la 	 21
# kärlekens 	 21
# spirrtus 	 21
# teatern 	 21
# palestina 	 21
# bergh 	 21
# kaptenen 	 21
# majorska 	 21
# fuchs 	 21
# juan 	 21
# berger 	 21
# vägg 	 20
# sörmland 	 20
# sovit 	 20
# vaknat 	 20
# svänga 	 20
# fläck 	 20
# torp 	 20
# härad 	 20
# galna 	 20
# tvang 	 20
# modet 	 20
# ingalunda 	 20
# förråda 	 20
# vildgåsen 	 20
# vingen 	 20
# skrattat 	 20
# förföljde 	 20
# uppfostran 	 16
# drömmer 	 16
# vördnad 	 16
# skälvande 	 16
# lasset 	 16
# supa 	 16
# nio 	 16
# svarten 	 16
# göteborg 	 16
# rynkor 	 16
# ödmjukt 	 16
# leendet 	 16
# förhoppningar 	 16
# ånger 	 16
# svek 	 16
# vari 	 16
# julafton 	 16
# tillhöra 	 16
# mördare 	 16
# rut 	 16
# fattat 	 16
# examen 	 16
# natur 	 16
# lyst 	 16
# stoft 	 16
# tösen 	 16
# däraf 	 16
# fostermodern 	 16
# blefve 	 16
# hviskade 	 16
# hvilade 	 16
# skrattande 	 16
# slaget 	 16
# trollkäringen 	 16
# mjöl 	 16
# hemåt 	 16
# munken 	 16
# fattige 	 16
# korten 	 16
# jokinen 	 16
# frykstedt 	 16
# kval 	 16
# födelsedag 	 16
# jerusalems 	 16
# brudkrona 	 16
# slommen 	 16
# ingenjörn 	 16
# ingborg 	 16
# albert 	 15
# sorger 	 15
# verka 	 15
#  	 15
# lutar 	 15
# barnens 	 15
# bössa 	 15
# sinnelag 	 15
# högra 	 15
# slapp 	 15
# räcka 	 15
# ring 	 15
# bakåt 	 15
# vassa 	 15
# oväsen 	 15
# gåskarlens 	 15
# hittade 	 15
# herrgårdarna 	 15
# orkar 	 15
# förargad 	 15
# sprickor 	 15
# sovplats 	 15
# sovo 	 15
# snabb 	 15
# skäms 	 15
# svårare 	 15
# räddade 	 15
# försvunnit 	 15
# missräkning 	 15
# leken 	 15
# antingen 	 15
# skuggan 	 15
# sällskapet 	 15
# tiders 	 15
# änka 	 15
# ilade 	 15
# bekymrad 	 15
# snabba 	 15
# mården 	 15
# invånare 	 15
# aktning 	 15
# skaror 	 15
# striden 	 15
# varelser 	 15
# budskap 	 15
# mossar 	 15
# lossa 	 15
# invändningar 	 15
# benet 	 15
# svårigheter 	 15
# naken 	 15
# översta 	 15
# ljudet 	 15
# ringar 	 15
# oupphörligt 	 15
# synnerligen 	 15
# förtjänat 	 15
# lustighet 	 15
# brinner 	 15
# molnen 	 15
# larver 	 15
# tuvor 	 15
# uppståndelse 	 15
# trappstegen 	 15
# grus 	 15
# handel 	 15
# jätte 	 15
# bergväggen 	 15
# branten 	 15
# klyftan 	 15
# förfölja 	 15
# yngsta 	 15
# tornet 	 15
# skred 	 15
# grågåsen 	 15
# sjönko 	 15
# piska 	 15
# dånade 	 15
# skyddade 	 15
# tröstade 	 15
# åja 	 15
# dold 	 15
# förmår 	 15
# lås 	 15
# bukt 	 15
# sorglösa 	 15
# ...
# pratsam 	 1
# friheter 	 1
# hemtrevligt 	 1
# utvecklar 	 1
# gräsvippor 	 1
# övertygar 	 1
# förvaltarplats 	 1
# hovrätten 	 1
# krasar 	 1
# stapplar 	 1
# beundrat 	 1
# ungkarlshem 	 1
# undanbett 	 1
# borgmästarinnan 	 1
# löjligaste 	 1
# schäskärra 	 1
# rotrista 	 1
# berge 	 1
# skälld 	 1
# halvslummern 	 1
# förblandar 	 1
# sötman 	 1
# bäret 	 1
# nerverna 	 1
# avtryck 	 1
# rannsakar 	 1
# sammanknutna 	 1
# småsummor 	 1
# sorgbundenhet 	 1
# gulnad 	 1
# hopskrumpen 	 1
# uppstramad 	 1
# marscherande 	 1
# fjäderbuske 	 1
# hoplänkade 	 1
# halskrage 	 1
# barnungarna 	 1
# hedersvakt 	 1
# framsade 	 1
# välkomsthälsning 	 1
# gullborg 	 1
# övertänkta 	 1
# gnällig 	 1
# guldkronan 	 1
# guldtronen 	 1
# guldklädda 	 1
# krigsöverstarna 	 1
# klädeskappa 	 1
# stadsfru 	 1
# sjövan 	 1
# sönderblåst 	 1
# packlårar 	 1
# tioriksdaler 	 1
# bengtsas 	 1
# koffertarna 	 1
# överkörd 	 1
# landgång 	 1
# månntro 	 1
# gottgörelse 	 1
# lastångaren 	 1
# klenoderna 	 1
# nödgad 	 1
# pomp 	 1
# draggade 	 1
# draggningen 	 1
# dragglinorna 	 1
# nygårds 	 1
# storviks 	 1
# torparna 	 1
# sängdags 	 1
# obegravd 	 1
# pappstjärnorna 	 1
# sjövattnet 	 1
# blankslitna 	 1
# hulpna 	 1
# likkistan 	 1
# sågspånsbädden 	 1
# alomkransade 	 1
# underkastade 	 1
# överenskommelsen 	 1
# drängpojke 	 1
# klarseende 	 1
# begravts 	 1
# avskedsorden 	 1
# färdesättet 	 1
# talt 	 1
# handelsbo 	 1
# småbåtarna 	 1
# fortfärdiga 	 1
# linnärt 	 1
# stocka 	 1
# högfärda 	 1
# hårdheta 	 1
# lusta 	 1
# kejsarrike 	 1
# avskedsord 	 1
# stålsatt 	 1
# feberdrömmar 	 1
# kejsarns 	 1
# kyrkbesök 	 1
# prästval 	 1
# begravningsfolket 	 1
# begravningsfölje 	 1
# likfölje 	 1
# utstrött 	 1
# sports 	 1
# översköljd 	 1
# hanterats 	 1
# repad 	 1
# kantstött 	 1
# storkarls 	 1
# sorgmodigt 	 1
# fredags 	 1
# återlämnade 	 1
# knappen 	 1
# skurvis 	 1
# förenades 	 1
# prestaver 	 1
# nedsänkta 	 1
# igensnöad 	 1
# beskedliga 	 1
# doms 	 1
# ömheten 	 1
# förrättat 	 1
# vigdes 	 1

# %%
len(frequency)
# Out:
# 41032

# %% [markdown]
# #### Bigrams

# %%
def bigrams(words):
    bigrams = []
    for i in range(len(words) - 1):
        bigrams.append((words[i], words[i + 1]))
    frequency_bigrams = {}
    for i in range(len(words) - 1):
        if bigrams[i] in frequency_bigrams:
            frequency_bigrams[bigrams[i]] += 1
        else:
            frequency_bigrams[bigrams[i]] = 1
    return frequency_bigrams

# %%
frequency_bigrams = bigrams(words)
list(frequency_bigrams.items())[:20]
# Out:
# [(('<s>', 'selma'), 8),
#  (('selma', 'lagerlöf'), 11),
#  (('lagerlöf', 'nils'), 1),
#  (('nils', 'holgerssons'), 6),
#  (('holgerssons', 'underbara'), 4),
#  (('underbara', 'resa'), 4),
#  (('resa', 'genom'), 6),
#  (('genom', 'sverige'), 5),
#  (('sverige', '</s>'), 17),
#  (('</s>', '<s>'), 59046),
#  (('<s>', 'första'), 11),
#  (('första', 'bandet'), 1),
#  (('bandet', 'bokutgåva'), 2),
#  (('bokutgåva', 'albert'), 11),
#  (('albert', 'bonniers'), 11),
#  (('bonniers', 'förlag'), 11),
#  (('förlag', 'stockholm'), 10),
#  (('stockholm', '</s>'), 24),
#  (('<s>', 'den'), 1375),
#  (('den', 'kristliga'), 2)]

# %%
frequency_bigrams[('<s>', 'selma')]
# Out:
# 8

# %%
len(frequency_bigrams)
# Out:
# 320138

# %% [markdown]
# In the report, tell what is the possible number of bigrams and their real number? Explain why such a difference. What would be the possible number of 4-grams.
#
# Propose a solution to cope with bigrams unseen in the corpus.

# %% [markdown]
# ### Computing the likelihood of a sentence
# You will now compute the likelihood of a sentence using a bigram and a trigram models.
#
# In both models, you will ignore the start of sentence symbol, `<s>`, as this factor is common to both models: $P(<s>)$. This will save you one multiplication.

# %% [markdown]
# #### Unigrams

# %% [markdown]
# Write a program to compute a sentence's probability using unigrams. You may find useful the dictionaries that we saw in the mutual information program: [<a href="https://github.com/pnugues/ilppp/tree/master/programs/ch05/python">Program folder</a>]. Your function will return the perplexity.

# %% [markdown]
# Your function should print and tabulate the results as in the examples below with the sentence _Det var en gång en katt som hette Nils_.
#
# Your figures might be slightly different because of differences in the sentence segmentation.

# %% [markdown]
# ```
# =====================================================
# wi 	 C(wi) 	 #words 	 P(wi)
# =====================================================
# det 	 21108 	 1041631 	 0.0202643738521607
# var 	 12090 	 1041631 	 0.01160679741674355
# en 	 13514 	 1041631 	 0.01297388422579589
# gång 	 1332 	 1041631 	 0.001278763784871994
# en 	 13514 	 1041631 	 0.01297388422579589
# katt 	 16 	 1041631 	 1.5360525944408337e-05
# som 	 16288 	 1041631 	 0.015637015411407686
# hette 	 97 	 1041631 	 9.312318853797554e-05
# nils 	 87 	 1041631 	 8.352285982272032e-05
# </s> 	 59047 	 1041631 	 0.056687060964967444
# =====================================================
# Prob. unigrams:	 5.361459667285409e-27
# Geometric mean prob.: 0.0023600885848765307
# Entropy rate:	 8.726943273141258
# Perplexity:	 423.71290908655254
# ```

# %%
# Write your code
def unigram_lm(frequency, sent_words):
    probUnigram = 1
    print("=====================================================")
    print("wi 	 C(wi) 	 #words 	 P(wi)")
    print("=====================================================")
    for word in sent_words:
        print(word + "\t" + str(frequency[word]) + "\t" + str(sum(frequency.values())) + "\t\t" + str(frequency[word]/sum(frequency.values())))
        prob = frequency[word]/sum(frequency.values())
        probUnigram *= prob
    print("=====================================================")
    # Formulars in lecture 05_2
    entropy = -1/len(sent_words)*math.log2(probUnigram)
    perplexity = 2**entropy
    print("Prob. unigrams:	 " + str(probUnigram))
    print("Geometric mean prob.: " + str(probUnigram**(1/len(sent_words))))
    print("Entropy rate:	 " + str(entropy))
    print("Perplexity:	 " + str(perplexity))
    return perplexity

# %%
sentence = 'det var en gång en katt som hette nils </s>'
sent_words = sentence.split()
sent_words
# Out:
# ['det', 'var', 'en', 'gång', 'en', 'katt', 'som', 'hette', 'nils', '</s>']

# %%
perplexity_unigrams = unigram_lm(frequency, sent_words)
# Out:
# =====================================================
# wi 	 C(wi) 	 #words 	 P(wi)
# =====================================================
# det	21108	1041575		0.020265463360775747
# var	12090	1041575		0.011607421453087872
# en	13514	1041575		0.01297458176319516
# gång	1332	1041575		0.0012788325372632792
# en	13514	1041575		0.01297458176319516
# katt	16	1041575		1.536135179895831e-05
# som	16288	1041575		0.01563785613133956
# hette	97	1041575		9.312819528118474e-05
# nils	87	1041575		8.35273504068358e-05
# </s>	59047	1041575		0.0566901087295682
# =====================================================
# Prob. unigrams:	 5.364342939182855e-27
# Geometric mean prob.: 0.0023602154744051325
# Entropy rate:	 8.726865709115128
# Perplexity:	 423.6901295005871

# %%
perplexity_unigrams = unigram_lm(frequency, sent_words)
# Out:
# Unigram model
# =====================================================
# wi 	 C(wi) 	 #words 	 P(wi)
# =====================================================
# det 	 21108 	 1041631 	 0.0202643738521607
# var 	 12090 	 1041631 	 0.01160679741674355
# en 	 13514 	 1041631 	 0.01297388422579589
# gång 	 1332 	 1041631 	 0.001278763784871994
# en 	 13514 	 1041631 	 0.01297388422579589
# katt 	 16 	 1041631 	 1.5360525944408337e-05
# som 	 16288 	 1041631 	 0.015637015411407686
# hette 	 97 	 1041631 	 9.312318853797554e-05
# nils 	 87 	 1041631 	 8.352285982272032e-05
# </s> 	 59047 	 1041631 	 0.056687060964967444
# =====================================================
# Prob. unigrams:	 5.361459667285409e-27
# Geometric mean prob.: 0.0023600885848765307
# Entropy rate:	 8.726943273141258
# Perplexity:	 423.71290908655254

# %%
perplexity_unigrams = int(perplexity_unigrams)
perplexity_unigrams
# Out:
# 423

# %% [markdown]
# #### Bigrams

# %% [markdown]
# Write a program to compute the sentence probability using bigrams. Your function will tabulate and print the results as below. It will return the perplexity.

# %% [markdown]
# ```
# =====================================================
# wi 	 wi+1 	 Ci,i+1 	 C(i) 	 P(wi+1|wi)
# =====================================================
# <s>	 det 	 5672 	 59047 	 0.09605907158704083
# det 	 var 	 3839 	 21108 	 0.1818741709304529
# var 	 en 	 712 	 12090 	 0.058891645988420185
# en 	 gång 	 706 	 13514 	 0.052242119283705785
# gång 	 en 	 20 	 1332 	 0.015015015015015015
# en 	 katt 	 6 	 13514 	 0.0004439840165754033
# katt 	 som 	 2 	 16 	 0.125
# som 	 hette 	 45 	 16288 	 0.002762770137524558
# hette 	 nils 	 0 	 97 	 0.0 	 *backoff: 	 8.352285982272032e-05
# nils 	 </s> 	 2 	 87 	 0.022988505747126436
# =====================================================
# Prob. bigrams:	 2.376007803503683e-19
# Geometric mean prob.: 0.013727289294133601
# Entropy rate:	 6.186809422848149
# Perplexity:	 72.84759420254609
# ```

# %%
print(sum(frequency.values()))
print(sum(frequency_bigrams.values()))
frequency_bigrams.get(('det','var1')) == None
# Out:
# 1041575
# 1041646
# True

# %%
# Write your code
def bigram_lm(frequency, frequency_bigrams, sent_words):
    firstword = "<s>"
    sum_freq = sum(frequency.values())
    sum_freq_bigrams = sum(frequency_bigrams.values())
    prob_bigrams = 1
    print("=====================================================")
    print("wi 	 wi+1 	 Ci,i+1 	 C(i) 	 P(wi+1|wi)")
    print("=====================================================")
    for word in sent_words:
        nextword = word
        ci_i1 = frequency_bigrams.get((firstword,nextword))
        ci = frequency[firstword]
        # P(w1,...,wn) = P(w1)*prod(P(wi|w(i-1)))
        # bigrams not in frequency_bigrams
        if frequency_bigrams.get((firstword,nextword)) == None:
            ci_i1 = 0
            # backoff c(wi)/#words
            prob = frequency[word]/sum_freq
        else:
            prob = ci_i1/frequency[firstword]
        prob_bigrams *= prob
        print(firstword + "\t" + nextword + "\t" + str(ci_i1) + "\t\t" + str(ci) + "\t" + str(prob))
        firstword = nextword
    print("=====================================================")
    # Formulars in lecture 05_2
    entropy = -1/len(sent_words)*math.log2(prob_bigrams)
    perplexity = 2**entropy
    print("Prob. bigrams:	 " + str(prob_bigrams))
    print("Geometric mean prob.: " + str(prob_bigrams**(1/len(sent_words))))
    print("Entropy rate:	 " + str(entropy))
    print("Perplexity:	 " + str(perplexity))
    return perplexity

# %%
perplexity_bigrams = bigram_lm(frequency, frequency_bigrams, sent_words)
# Out:
# =====================================================
# wi 	 wi+1 	 Ci,i+1 	 C(i) 	 P(wi+1|wi)
# =====================================================
# <s>	det	5672		59047	0.09605907158704083
# det	var	3839		21108	0.1818741709304529
# var	en	712		12090	0.058891645988420185
# en	gång	706		13514	0.052242119283705785
# gång	en	20		1332	0.015015015015015015
# en	katt	6		13514	0.0004439840165754033
# katt	som	2		16	0.125
# som	hette	45		16288	0.002762770137524558
# hette	nils	0		97	8.35273504068358e-05
# nils	</s>	2		87	0.022988505747126436
# =====================================================
# Prob. bigrams:	 2.3761355489247967e-19
# Geometric mean prob.: 0.013727363096750062
# Entropy rate:	 6.186801666445536
# Perplexity:	 72.8472025509946

# %%
perplexity_bigrams = bigram_lm(frequency, frequency_bigrams, sent_words)
# Out:
# Bigram model
# =====================================================
# wi 	 wi+1 	 Ci,i+1 	 C(i) 	 P(wi+1|wi)
# =====================================================
# <s>	 det 	 5672 	 59047 	 0.09605907158704083
# det 	 var 	 3839 	 21108 	 0.1818741709304529
# var 	 en 	 712 	 12090 	 0.058891645988420185
# en 	 gång 	 706 	 13514 	 0.052242119283705785
# gång 	 en 	 20 	 1332 	 0.015015015015015015
# en 	 katt 	 6 	 13514 	 0.0004439840165754033
# katt 	 som 	 2 	 16 	 0.125
# som 	 hette 	 45 	 16288 	 0.002762770137524558
# hette 	 nils 	 0 	 97 	 0.0 	 *backoff: 	 8.352285982272032e-05
# nils 	 </s> 	 2 	 87 	 0.022988505747126436
# =====================================================
# Prob. bigrams:	 2.376007803503683e-19
# Geometric mean prob.: 0.013727289294133601
# Entropy rate:	 6.186809422848149
# Perplexity:	 72.84759420254609

# %%
perplexity_bigrams = int(perplexity_bigrams)
perplexity_bigrams
# Out:
# 72

# %% [markdown]
# In addition to this sentence, _Det var en gång en katt som hette Nils_, write three other sentences that will form your test set and run your programs on them. You will insert them in your report.

# %%
sentence1 = 'men liksom engelbrekt med mod från stad till stad från flod till flod vi fram till målet lände </s>'
sent_words1 = sentence1.split()
perplexity_unigrams = unigram_lm(frequency, sent_words1)
perplexity_bigrams = bigram_lm(frequency, frequency_bigrams, sent_words1)

sentence2 = 'där förr vi sutto du och jag ett släkte sitter nu i dag som kan vad vi ej visste </s>'
sent_words2 = sentence2.split()
perplexity_unigrams = unigram_lm(frequency, sent_words2)
perplexity_bigrams = bigram_lm(frequency, frequency_bigrams, sent_words2)

sentence3 = 'han var så där en fjorton år gammal lång och ranglig och linhårig </s>'
sent_words3 = sentence3.split()
perplexity_unigrams = unigram_lm(frequency, sent_words3)
perplexity_bigrams = bigram_lm(frequency, frequency_bigrams, sent_words3)
# Out:
# =====================================================
# wi 	 C(wi) 	 #words 	 P(wi)
# =====================================================
# men	8144	1041575		0.00781892806566978
# liksom	318	1041575		0.00030530686700429635
# engelbrekt	1	1041575		9.600844874348943e-07
# med	9140	1041575		0.008775172215154933
# mod	108	1041575		0.00010368912464296858
# från	2347	1041575		0.002253318292009697
# stad	111	1041575		0.00010656937810527326
# till	9139	1041575		0.0087742121306675
# stad	111	1041575		0.00010656937810527326
# från	2347	1041575		0.002253318292009697
# flod	9	1041575		8.640760386914048e-06
# till	9139	1041575		0.0087742121306675
# flod	9	1041575		8.640760386914048e-06
# vi	2105	1041575		0.0020209778460504525
# fram	2019	1041575		0.0019384105801310515
# till	9139	1041575		0.0087742121306675
# målet	13	1041575		1.2481098336653625e-05
# lände	2	1041575		1.9201689748697887e-06
# </s>	59047	1041575		0.0566901087295682
# =====================================================
# Prob. unigrams:	 3.2279531908300972e-65
# Geometric mean prob.: 0.0004033973231557538
# Entropy rate:	 11.27551086893207
# Perplexity:	 2478.9455521842765
# =====================================================
# wi 	 wi+1 	 Ci,i+1 	 C(i) 	 P(wi+1|wi)
# =====================================================
# <s>	men	3824		59047	0.06476196927871018
# men	liksom	2		8144	0.0002455795677799607
# liksom	engelbrekt	1		318	0.0031446540880503146
# engelbrekt	med	1		1	1.0
# med	mod	2		9140	0.0002188183807439825
# mod	från	1		108	0.009259259259259259
# från	stad	1		2347	0.00042607584149978694
# stad	till	1		111	0.009009009009009009
# till	stad	2		9139	0.000218842324105482
# stad	från	1		111	0.009009009009009009
# från	flod	1		2347	0.00042607584149978694
# flod	till	1		9	0.1111111111111111
# till	flod	1		9139	0.000109421162052741
# flod	vi	1		9	0.1111111111111111
# vi	fram	2		2105	0.0009501187648456057
# fram	till	514		2019	0.254581475978207
# till	målet	4		9139	0.000437684648210964
# målet	lände	1		13	0.07692307692307693
# lände	</s>	1		2	0.5
# =====================================================
# Prob. bigrams:	 1.7972700960863656e-42
# Geometric mean prob.: 0.006351471983648516
# Entropy rate:	 7.298693302633806
# Perplexity:	 157.4438181534044
# =====================================================
# wi 	 C(wi) 	 #words 	 P(wi)
# =====================================================
# där	4238	1041575		0.0040688380577490815
# förr	376	1041575		0.00036099176727552026
# vi	2105	1041575		0.0020209778460504525
# sutto	191	1041575		0.0001833761371000648
# du	4359	1041575		0.004185008280728704
# och	36356	1041575		0.034904831625183014
# jag	9511	1041575		0.00913136355999328
# ett	5060	1041575		0.004858027506420565
# släkte	10	1041575		9.600844874348943e-06
# sitter	242	1041575		0.0002323404459592444
# nu	4084	1041575		0.003920985046684108
# i	16508	1041575		0.015849074718575235
# dag	942	1041575		0.0009043995871636704
# som	16288	1041575		0.01563785613133956
# kan	2078	1041575		0.0019950555648897104
# vad	1961	1041575		0.0018827256798598277
# vi	2105	1041575		0.0020209778460504525
# ej	1806	1041575		0.001733912584307419
# visste	874	1041575		0.0008391138420180976
# </s>	59047	1041575		0.0566901087295682
# =====================================================
# Prob. unigrams:	 4.329915846449146e-54
# Geometric mean prob.: 0.002146960096964883
# Entropy rate:	 8.863488906900823
# Perplexity:	 465.7748420260263
# =====================================================
# wi 	 wi+1 	 Ci,i+1 	 C(i) 	 P(wi+1|wi)
# =====================================================
# <s>	där	489		59047	0.008281538435483599
# där	förr	4		4238	0.0009438414346389807
# förr	vi	1		376	0.0026595744680851063
# vi	sutto	4		2105	0.0019002375296912114
# sutto	du	1		191	0.005235602094240838
# du	och	31		4359	0.007111722872218399
# och	jag	443		36356	0.012185058862361096
# jag	ett	6		9511	0.0006308484912206919
# ett	släkte	1		5060	0.0001976284584980237
# släkte	sitter	1		10	0.1
# sitter	nu	3		242	0.012396694214876033
# nu	i	69		4084	0.016895200783545544
# i	dag	228		16508	0.013811485340440998
# dag	som	43		942	0.045647558386411886
# som	kan	61		16288	0.0037450884086444006
# kan	vad	1		2078	0.00048123195380173246
# vad	vi	22		1961	0.011218765935747067
# vi	ej	13		2105	0.006175771971496437
# ej	visste	9		1806	0.0049833887043189366
# visste	</s>	16		874	0.018306636155606407
# =====================================================
# Prob. bigrams:	 3.3611439867973965e-46
# Geometric mean prob.: 0.00532505816483886
# Entropy rate:	 7.552987000888628
# Perplexity:	 187.7913759896481
# =====================================================
# wi 	 C(wi) 	 #words 	 P(wi)
# =====================================================
# han	21589	1041575		0.020727263999231933
# var	12090	1041575		0.011607421453087872
# så	9149	1041575		0.008783812975541847
# där	4238	1041575		0.0040688380577490815
# en	13514	1041575		0.01297458176319516
# fjorton	21	1041575		2.0161774236132778e-05
# år	706	1041575		0.0006778196481290353
# gammal	491	1041575		0.0004714014833305331
# lång	340	1041575		0.00032642872572786406
# och	36356	1041575		0.034904831625183014
# ranglig	2	1041575		1.9201689748697887e-06
# och	36356	1041575		0.034904831625183014
# linhårig	1	1041575		9.600844874348943e-07
# </s>	59047	1041575		0.0566901087295682
# =====================================================
# Prob. unigrams:	 2.987267308032199e-41
# Geometric mean prob.: 0.001274608236138621
# Entropy rate:	 9.615730396503807
# Perplexity:	 784.554792325416
# =====================================================
# wi 	 wi+1 	 Ci,i+1 	 C(i) 	 P(wi+1|wi)
# =====================================================
# <s>	han	5059		59047	0.08567751113519738
# han	var	986		21589	0.045671406734911296
# var	så	504		12090	0.04168734491315137
# så	där	84		9149	0.009181331293037491
# där	en	52		4238	0.012269938650306749
# en	fjorton	1		13514	7.399733609590054e-05
# fjorton	år	5		21	0.23809523809523808
# år	gammal	28		706	0.039660056657223795
# gammal	lång	1		491	0.002036659877800407
# lång	och	26		340	0.07647058823529412
# och	ranglig	1		36356	2.750577621300473e-05
# ranglig	och	1		2	0.5
# och	linhårig	1		36356	2.750577621300473e-05
# linhårig	</s>	1		1	1.0
# =====================================================
# Prob. bigrams:	 7.5650951539150735e-28
# Geometric mean prob.: 0.011555066701501695
# Entropy rate:	 6.435330602003108
# Perplexity:	 86.54212267507208

# %% [markdown]
# ### Online prediction of words

# %% [markdown]
# You will now carry out an online prediction of words. You will consider two cases:
# 1. Prediction of the current word a user is typing;
# 2. Prediction of the next word.
#
# Ideally, you would write a loop that reads the words and apply the models while typing. As the Jupyter labs are not designed for interactive input and output, we will simplify the experimental settings with constant strings at a given time of the input.
#
# We will assume the user is typing the phrase: _Det var en gång_.

# %% [markdown]
# #### Trigrams

# %% [markdown]
# To have a more accurate prediction, you will use a trigram counting function. Program this function following the model of your bigram counting function.

# %%
# Write your code
def trigrams(words):
    trigrams = [tuple(words[idx:idx + 3])
                for idx in range(len(words) - 2)]
    frequencies = {}
    for trigram in trigrams:
        if trigram in frequencies:
            frequencies[trigram] += 1
        else:
            frequencies[trigram] = 1
    return frequencies

# %%
frequency_trigrams = trigrams(words)
frequency_trigrams[('det', 'var', 'en')]
# Out:
# 330

# %% [markdown]
# #### Prediction

# %% [markdown]
# The user starts typing _Det var en gång_. After the 2nd character, your program tries to help the user with suggested words.

# %%
starting_text = 'De'.lower()
starting_text
# Out:
# 'de'

# %% [markdown]
# Write a program to rank the five first candidates at this point. Assign these predictions in a list that you will call `current_word_predictions_1`. Note that you are starting a sentence and you can then use the bigram frequencies. Write a sorting key that will enable you to have a deterministic ranking of the words or bigrams with identical frequencies: When two words have the same frequency, you will sort them by alphabetic order. You can do this with a tuple.

# %%
cand_nbr = 5

# %%
# Write your code here
candidates = {}
# Combining the partial input with possible next words
for bigram in frequency_bigrams.keys():
    if bigram[0] == '<s>' and bigram[1].startswith(starting_text):
        candidates[bigram] = frequency_bigrams[bigram]

def sorting_key(candidate):
    # Create a tuple with frequency and the candidate for sorting, reverse the sorting order.
    return (-candidates[candidate], candidate)

# Sort the candidates based on the sorting key
sorted_candidates = sorted(candidates.keys(), key=sorting_key)

# Get the top five candidates
current_word_predictions_1 = [element[1] for element in sorted_candidates[:cand_nbr]]
current_word_predictions_1
# Out:
# ['det', 'de', 'den', 'detta', 'denna']

# %%
current_word_predictions_1
# Out:
# ['det', 'de', 'den', 'detta', 'denna']

# %% [markdown]
# Let us now suppose that the user has typed: _Det var en_. After detecting a space, your program starts predicting a next possible word.

# %%
current_text = "Det var en ".lower()
current_text
# Out:
# 'det var en '

# %% [markdown]
# Tokenize this text and return a list of tokens. Call it `tokens`.

# %%
# Write your code here
tokens = tokenize(current_text)

# %%
tokens
# Out:
# ['det', 'var', 'en']

# %% [markdown]
# Write a program to propose the five next possible words ranked by frequency using a trigram model. Assign these predictions to a variable that you will call `next_word_predictions`. Write a sorting key that will enable you have a deterministic ranking of the words or bigrams with identical frequencies: When two words have the same frequency, you will sort them by alphabetic order. You can do this with a tuple.

# %%
# Write your code here
candidates = {}
# Combining 2 inputs with possible next word
for trigram in frequency_trigrams.keys():
    if trigram[0] == tokens[1] and trigram[1] == tokens[2]:
        candidates[trigram] = frequency_trigrams[trigram]

def sorting_key(candidate):
    # Create a tuple with frequency and the candidate for sorting, reverse the sorting order.
    return (-candidates[candidate], candidate)

# Sort the candidates based on the sorting key
sorted_candidates = sorted(candidates.keys(), key=sorting_key)

# Get the top five candidates
next_word_predictions = [element[2] for element in sorted_candidates[:cand_nbr]]
next_word_predictions
# Out:
# ['stor', 'liten', 'gammal', 'god', 'sådan']

# %%
next_word_predictions
# Out:
# ['stor', 'liten', 'gammal', 'god', 'sådan']

# %% [markdown]
# Finally, let us suppose that the user has typed _Det var en g_, rank the five possible candidates. Assign these predictions in a list that you will call `current_word_predictions_2`

# %%
current_text = "Det var en g".lower()
current_text = current_text.split()
current_text
# Out:
# ['det', 'var', 'en', 'g']

# %%
# Write your code here
candidates = {}
# Combining 2 inputs with possible next word
for trigram in frequency_trigrams.keys():
    if trigram[0] == current_text[1] and trigram[1] == current_text[2] and trigram[2].startswith(current_text[3]):
        candidates[trigram] = frequency_trigrams[trigram]

def sorting_key(candidate):
    # Create a tuple with frequency and the candidate for sorting, reverse the sorting order.
    return (-candidates[candidate], candidate)

# Sort the candidates based on the sorting key
sorted_candidates = sorted(candidates.keys(), key=sorting_key)

# Get the top five candidates
next_word_predictions = [element[2] for element in sorted_candidates[:cand_nbr]]
next_word_predictions
# Out:
# ['gammal', 'god', 'gång', 'ganska', 'glädje']

# %%
current_word_predictions_2
# Out:
# ['gammal', 'god', 'gång', 'ganska', 'glädje']

# %% [markdown]
# ## Turning in your assignment

# %% [markdown]
# Now your are done with the program. To complete this assignment, you will:
# 1. Write a short individual report on your program. You will include the __regular expression you used to segment the text__ and the __unigram and bigram tables__ for _Det var en gång en katt som hette Nils_ and __two other sentences__.
# 2. Execute the Jupyter notebook by Peter Norvig here: <a href="http://nbviewer.jupyter.org/url/norvig.com/ipython/How%20to%20Do%20Things%20with%20Words.ipynb">https://nbviewer.jupyter.org/url/norvig.com/ipython/How to Do Things with Words.ipynb</a>. Just run all the cells and be sure that you understand the code. You will find the data here: <a href="http://norvig.com/ngrams/">http://norvig.com/ngrams/</a>.
# 3. In your report, after the description of your program, you will describe one experiment with Norvig's notebook and a __long string of words your will create yourself or copy from a text you like__. You will remove all the punctuation and white spaces from this string. You will set this string in lowercase letters. You will just add a cell at the end of Sect. 7 in Norvig's notebook, where you will use your string and run the notebook cell with the <tt>segment()</tt> and <tt>segment2()</tt> functions. __You will comment the segmentation results you obtained__ with the unigram and bigram models.
#
# Submit your report as well as your notebook (for archiving purposes) to Canvas: https://canvas.education.lu.se/. To write your report, you can either
# 1. Write directly your text in Canvas, or
# 2. Use Latex and Overleaf (www.overleaf.com). This will probably help you structure your text. You will then upload a PDF file in Canvas.
#
# The submission deadline is September 22, 2023. You will have only three submission attempts. The deadline for the second and third ones are one week after you are noticed of your result.
